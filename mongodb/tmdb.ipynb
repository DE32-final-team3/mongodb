# %% [markdown]
# ## Search

# %%
import requests
from odmantic import AIOEngine, Model
from motor.motor_asyncio import AsyncIOMotorClient
# import asyncio
from typing import Optional, List

# Odmantic 모델 정의
class Movie(Model):
    movie_id: int
    title: str
    original_title: Optional[str] = None
    poster_path: Optional[str] = None
    language: str
    genre_ids: List[int]
    popularity: float
    release_date: Optional[str] = None

# API 요청 및 MongoDB 저장 함수
async def fetch_and_store_movies():
    # API 요청
    search_query = "기생충"
    url = f"https://api.themoviedb.org/3/search/movie?query={search_query}&include_adult=false&language=ko-KO&page=1"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw"
    }
    response = requests.get(url, headers=headers)
    data = response.json()

    # MongoDB 연결 설정
    client = AsyncIOMotorClient("mongodb://user:team3@localhost:27017/")
    engine = AIOEngine(client=client, database="movies_db")

    # 필요한 컬럼만 추출
    if "results" in data:
        movies = [
            Movie(
                movie_id=item["id"],
                title=item.get("title") or item.get("name"),
                original_title=item.get("original_title") or item.get("original_name"),
                poster_path=item.get("poster_path"),
                language=item.get("original_language"),
                genre_ids=item.get("genre_ids", []),
                popularity=item.get("popularity", 0.0),
                release_date=item.get("release_date") or item.get("first_air_date"),
            )
            for item in data["results"]
        ]

        # MongoDB에 저장
        if movies:
            await engine.save_all(movies)
            print("필터링된 데이터가 성공적으로 저장되었습니다!")
        else:
            print("저장할 데이터가 없습니다.")
    else:
        print("API 응답에 'results' 키가 없습니다.")

# %% [markdown]
# ## Details

# %% [markdown]
# ## Cast

# %%
import requests

movie_id = 313369
url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?language=ko-KR"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw"
}

response = requests.get(url, headers=headers)
response.json()
# Out:
# {'id': 313369,
#  'cast': [{'adult': False,
#    'gender': 2,
#    'id': 30614,
#    'known_for_department': 'Acting',
#    'name': '라이언 고슬링',
#    'original_name': 'Ryan Gosling',
#    'popularity': 55.822,
#    'profile_path': '/lyUyVARQKhGxaxy0FbPJCQRpiaW.jpg',
#    'cast_id': 26,
#    'character': 'Sebastian',
#    'credit_id': '575d52d99251415a0a004d9f',
#    'order': 0},
#   {'adult': False,
#    'gender': 1,
#    'id': 54693,
#    'known_for_department': 'Acting',
#    'name': '엠마 스톤',
#    'original_name': 'Emma Stone',
#    'popularity': 65.466,
#    'profile_path': '/cZ8a3QvAnj2cgcgVL6g4XaqPzpL.jpg',
#    'cast_id': 27,
#    'character': 'Mia',
#    'credit_id': '575d52e3c3a3684516000671',
#    'order': 1},
#   {'adult': False,
#    'gender': 2,
#    'id': 113461,
#    'known_for_department': 'Acting',
#    'name': '존 레전드',
#    'original_name': 'John Legend',
#    'popularity': 7.476,
#    'profile_path': '/cCv0YBy2YFFWp9h3kvNPmwWwrCD.jpg',
#    'cast_id': 34,
#    'character': 'Keith',
#    'credit_id': '575d53ed9251412443001dc0',
#    'order': 2},
#   {'adult': False,
#    'gender': 1,
#    'id': 14892,
#    'known_for_department': 'Acting',
#    'name': '로즈메리 디윗',
#    'original_name': 'Rosemarie DeWitt',
#    'popularity': 37.484,
#    'profile_path': '/44sxIdGtYN24R14OmnZbCpcd8J8.jpg',
#    'cast_id': 32,
#    'character': 'Laura',
#    'credit_id': '575d53d49251412443001db8',
#    'order': 3},
#   {'adult': False,
#    'gender': 2,
#    'id': 18999,
#    'known_for_department': 'Acting',
#    'name': 'J.K. 시몬스',
#    'original_name': 'J.K. Simmons',
#    'popularity': 54.674,
#    'profile_path': '/ScmKoJ9eiSUOthAt1PDNLi8Fkw.jpg',
#    'cast_id': 29,
#    'character': 'Bill',
#    'credit_id': '575d52fac3a3685e2a000272',
#    'order': 4},
#   {'adult': False,
#    'gender': 1,
#    'id': 1123299,
#    'known_for_department': 'Acting',
#    'name': 'Amiée Conn',
#    'original_name': 'Amiée Conn',
#    'popularity': 1.374,
#    'profile_path': '/wAcmKIkZOfuS3gKnUTUW9Epu6Yy.jpg',
#    'cast_id': 84,
#    'character': 'Famous Actress',
#    'credit_id': '575d5886c3a36873a3003555',
#    'order': 5},
#   {'adult': False,
#    'gender': 1,
#    'id': 142263,
#    'known_for_department': 'Acting',
#    'name': 'Terry Walters',
#    'original_name': 'Terry Walters',
#    'popularity': 3.294,
#    'profile_path': '/ixN4VkUNqy2xObaddCW68rhFbyA.jpg',
#    'cast_id': 66,
#    'character': 'Linda',
#    'credit_id': '575d56bac3a36810a4004c7d',
#    'order': 6},
#   {'adult': False,
#    'gender': 2,
#    'id': 1697098,
#    'known_for_department': 'Acting',
#    'name': 'Thom Shelton',
#    'original_name': 'Thom Shelton',
#    'popularity': 0.59,
#    'profile_path': '/pJy38LQINpvPvTKgQJvxOwrWDkb.jpg',
#    'cast_id': 342,
#    'character': 'Coffee Spiller',
#    'credit_id': '58efc5b1c3a3686b4d000827',
#    'order': 7},
#   {'adult': False,
#    'gender': 1,
#    'id': 1324161,
#    'known_for_department': 'Acting',
#    'name': 'Cinda Adams',
#    'original_name': 'Cinda Adams',
#    'popularity': 5.771,
#    'profile_path': '/7CZXKhAEyjslPo7OH6TrYWCWEZz.jpg',
#    'cast_id': 88,
#    'character': 'Casting Director',
#    'credit_id': '575d59c4c3a36810a4004d40',
#    'order': 8},
#   {'adult': False,
#    'gender': 1,
#    'id': 1486488,
#    'known_for_department': 'Acting',
#    'name': 'Callie Hernandez',
#    'original_name': 'Callie Hernandez',
#    'popularity': 7.384,
#    'profile_path': '/doMXlhTAYCy8gH43yYA6m9ymxhd.jpg',
#    'cast_id': 35,
#    'character': 'Tracy',
#    'credit_id': '575d53f8c3a3685e2a0002c4',
#    'order': 9},
#   {'adult': False,
#    'gender': 1,
#    'id': 1427680,
#    'known_for_department': 'Acting',
#    'name': '제시카 로테',
#    'original_name': 'Jessica Rothe',
#    'popularity': 20.059,
#    'profile_path': '/tVOO4zqN4YEdWvyQgqfqY0IdMRV.jpg',
#    'cast_id': 41,
#    'character': 'Alexis',
#    'credit_id': '575d54479251414ed500167e',
#    'order': 10},
#   {'adult': False,
#    'gender': 1,
#    'id': 1457238,
#    'known_for_department': 'Acting',
#    'name': '미즈노 소노야',
#    'original_name': 'Sonoya Mizuno',
#    'popularity': 16.873,
#    'profile_path': '/scbRPaGPw3VnR6mrmZQZi6Cuj1m.jpg',
#    'cast_id': 31,
#    'character': 'Caitlin',
#    'credit_id': '575d53cbc3a36873a3003410',
#    'order': 11},
#   {'adult': False,
#    'gender': 1,
#    'id': 156985,
#    'known_for_department': 'Acting',
#    'name': 'Claudine Claudio',
#    'original_name': 'Claudine Claudio',
#    'popularity': 0.876,
#    'profile_path': '/17mMdoaqw8CaUsIvc0ce5w71ihS.jpg',
#    'cast_id': 91,
#    'character': 'Karen',
#    'credit_id': '575d59f4c3a3681318001dc4',
#    'order': 12},
#   {'adult': False,
#    'gender': 2,
#    'id': 131947,
#    'known_for_department': 'Acting',
#    'name': 'Jason Fuchs',
#    'original_name': 'Jason Fuchs',
#    'popularity': 4.483,
#    'profile_path': '/fevls3rxpa1GQx4kSPNKNjRemKW.jpg',
#    'cast_id': 38,
#    'character': 'Carlo',
#    'credit_id': '575d541fc3a3685e2a0002cc',
#    'order': 13},
#   {'adult': False,
#    'gender': 2,
#    'id': 1475215,
#    'known_for_department': 'Acting',
#    'name': 'D.A. Wallach',
#    'original_name': 'D.A. Wallach',
#    'popularity': 0.238,
#    'profile_path': None,
#    'cast_id': 336,
#    'character': "80's singer",
#    'credit_id': '5859a7919251416fad06dce5',
#    'order': 14},
#   {'adult': False,
#    'gender': 2,
#    'id': 181763,
#    'known_for_department': 'Acting',
#    'name': 'Trevor Lissauer',
#    'original_name': 'Trevor Lissauer',
#    'popularity': 1.926,
#    'profile_path': '/hW3GDgV3q0Swo0EHf5W3mmZetjP.jpg',
#    'cast_id': 45,
#    'character': 'Valet',
#    'credit_id': '575d54af9251412443001de9',
#    'order': 15},
#   {'adult': False,
#    'gender': 1,
#    'id': 1634328,
#    'known_for_department': 'Acting',
#    'name': 'Olivia Hamilton',
#    'original_name': 'Olivia Hamilton',
#    'popularity': 2.888,
#    'profile_path': '/gfJ4zeUp8xZV0rVoWMkxsIiw4X0.jpg',
#    'cast_id': 81,
#    'character': 'Bree',
#    'credit_id': '575d57be9251415dd2002be3',
#    'order': 16},
#   {'adult': False,
#    'gender': 1,
#    'id': 1419625,
#    'known_for_department': 'Acting',
#    'name': 'Anna Chazelle',
#    'original_name': 'Anna Chazelle',
#    'popularity': 1.742,
#    'profile_path': '/lSkrk8rqWUHVOZAMVGpknQP7RkU.jpg',
#    'cast_id': 89,
#    'character': 'Sarah / Hula Hooper',
#    'credit_id': '575d59cf9251412b0c0032c4',
#    'order': 17},
#   {'adult': False,
#    'gender': 2,
#    'id': 1316159,
#    'known_for_department': 'Sound',
#    'name': 'Marius de Vries',
#    'original_name': 'Marius de Vries',
#    'popularity': 1.475,
#    'profile_path': '/xIMYzb0xd07ZVxr5vmtFwreuxm7.jpg',
#    'cast_id': 343,
#    'character': 'Clyde',
#    'credit_id': '58efc87fc3a3686b8e000aae',
#    'order': 18},
#   {'adult': False,
#    'gender': 2,
#    'id': 168877,
#    'known_for_department': 'Acting',
#    'name': 'Finn Wittrock',
#    'original_name': 'Finn Wittrock',
#    'popularity': 11.267,
#    'profile_path': '/gwGMGTmli0uBF7eAhhXePWhYNFJ.jpg',
#    'cast_id': 30,
#    'character': 'Greg Earnest',
#    'credit_id': '575d53bfc3a368451600069c',
#    'order': 19},
#   {'adult': False,
#    'gender': 2,
#    'id': 928532,
#    'known_for_department': 'Acting',
#    'name': 'Josh Pence',
#    'original_name': 'Josh Pence',
#    'popularity': 4.172,
#    'profile_path': '/tkDFl0BEVCUcwKR30ICeG3yCTbr.jpg',
#    'cast_id': 36,
#    'character': 'Josh',
#    'credit_id': '575d54019251412b0c003132',
#    'order': 20},
#   {'adult': False,
#    'gender': 1,
#    'id': 1473053,
#    'known_for_department': 'Acting',
#    'name': 'Nicole Coulon',
#    'original_name': 'Nicole Coulon',
#    'popularity': 3.142,
#    'profile_path': '/xNRgO2iG9zziOzbgK72yLRCPIRe.jpg',
#    'cast_id': 57,
#    'character': "Josh's Fiance",
#    'credit_id': '575d557992514123c2001dc3',
#    'order': 21},
#   {'adult': False,
#    'gender': 2,
#    'id': 53454,
#    'known_for_department': 'Acting',
#    'name': '데이먼 겁턴',
#    'original_name': 'Damon Gupton',
#    'popularity': 3.895,
#    'profile_path': '/bbbJiEx01uvOCKwiEHv9OmPI4r8.jpg',
#    'cast_id': 337,
#    'character': 'Harry',
#    'credit_id': '586c4584c3a368037b00180c',
#    'order': 22},
#   {'adult': False,
#    'gender': 0,
#    'id': 1818926,
#    'known_for_department': 'Acting',
#    'name': 'Christopher Michael Stevens',
#    'original_name': 'Christopher Michael Stevens',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 376,
#    'character': 'Malcolm',
#    'credit_id': '591cfce19251414a7b01487f',
#    'order': 23},
#   {'adult': False,
#    'gender': 0,
#    'id': 1818927,
#    'known_for_department': 'Acting',
#    'name': 'Keith Harris',
#    'original_name': 'Keith Harris',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 377,
#    'character': 'Cole',
#    'credit_id': '591cfcfa9251414ab1013bae',
#    'order': 24},
#   {'adult': False,
#    'gender': 0,
#    'id': 1784541,
#    'known_for_department': 'Sound',
#    'name': 'Kaveh Rastegar',
#    'original_name': 'Kaveh Rastegar',
#    'popularity': 0.001,
#    'profile_path': '/kfjgDX4nl4nUIvb3uVLHSPFJCuT.jpg',
#    'cast_id': 378,
#    'character': 'Tom',
#    'credit_id': '591cfd17c3a3687a640148eb',
#    'order': 25},
#   {'adult': False,
#    'gender': 2,
#    'id': 100538,
#    'known_for_department': 'Acting',
#    'name': 'David Douglas',
#    'original_name': 'David Douglas',
#    'popularity': 3.655,
#    'profile_path': '/lDdmA75f7irhs9kq0s3W3WbvL5w.jpg',
#    'cast_id': 48,
#    'character': 'Ty',
#    'credit_id': '575d54e4c3a36873a3003472',
#    'order': 26},
#   {'adult': False,
#    'gender': 2,
#    'id': 65885,
#    'known_for_department': 'Acting',
#    'name': 'Miles Anderson',
#    'original_name': 'Miles Anderson',
#    'popularity': 3.529,
#    'profile_path': '/i4VFdmtrRrQoagTlHHlC1klwJAE.jpg',
#    'cast_id': 380,
#    'character': 'Alistair',
#    'credit_id': '59e6b6609251416ead0023c1',
#    'order': 27},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634353,
#    'known_for_department': 'Acting',
#    'name': 'Bobo Chang',
#    'original_name': 'Bobo Chang',
#    'popularity': 0.696,
#    'profile_path': '/ti8xeMI8FUPcaWNlDaIodp5ugKn.jpg',
#    'cast_id': 354,
#    'character': "Photographer's Assistant",
#    'credit_id': '58efde2392514125a9001e1b',
#    'order': 28},
#   {'adult': False,
#    'gender': 1,
#    'id': 82988,
#    'known_for_department': 'Acting',
#    'name': '미건 페이',
#    'original_name': 'Meagen Fay',
#    'popularity': 4.195,
#    'profile_path': '/uGjLdLxUmSgIEJX8KFv85PaGiHl.jpg',
#    'cast_id': 333,
#    'character': 'Mrs. Dolan',
#    'credit_id': '57df4f7b9251416c1f003381',
#    'order': 29},
#   {'adult': False,
#    'gender': 2,
#    'id': 129478,
#    'known_for_department': 'Writing',
#    'name': 'John Hindman',
#    'original_name': 'John Hindman',
#    'popularity': 0.36,
#    'profile_path': None,
#    'cast_id': 356,
#    'character': 'Frank',
#    'credit_id': '58efe176c3a3686b4d001f6f',
#    'order': 30},
#   {'adult': False,
#    'gender': 1,
#    'id': 1212687,
#    'known_for_department': 'Acting',
#    'name': 'Valarie Rae Miller',
#    'original_name': 'Valarie Rae Miller',
#    'popularity': 4.487,
#    'profile_path': '/zVD40ujRFilHsDLkVl3vYiDfgPO.jpg',
#    'cast_id': 348,
#    'character': 'Amy Brandt',
#    'credit_id': '58efd38592514125cb0013d0',
#    'order': 31},
#   {'adult': False,
#    'gender': 1,
#    'id': 1634342,
#    'known_for_department': 'Acting',
#    'name': 'Nicole Wolf',
#    'original_name': 'Nicole Wolf',
#    'popularity': 1.049,
#    'profile_path': '/oppDjxZny3MwE6JLNHdtqOCCMN7.jpg',
#    'cast_id': 95,
#    'character': "Amy Brandt's Assistant",
#    'credit_id': '575d5a2ec3a36810a4004d63',
#    'order': 32},
#   {'adult': False,
#    'gender': 1,
#    'id': 1302576,
#    'known_for_department': 'Acting',
#    'name': 'Corrin Evans',
#    'original_name': 'Corrin Evans',
#    'popularity': 2.997,
#    'profile_path': '/9YTONcDc4czoXEeFVRHSClPPCCg.jpg',
#    'cast_id': 80,
#    'character': 'New Barista',
#    'credit_id': '575d57b4c3a36873a3003521',
#    'order': 33},
#   {'adult': False,
#    'gender': 2,
#    'id': 1141368,
#    'known_for_department': 'Acting',
#    'name': 'Kiff VandenHeuvel',
#    'original_name': 'Kiff VandenHeuvel',
#    'popularity': 1.53,
#    'profile_path': '/5vf1cIWjqH3xgbHWPhyIIEKDgdN.jpg',
#    'cast_id': 49,
#    'character': 'New Coffee Shop Manager',
#    'credit_id': '575d54f29251414ed50016b3',
#    'order': 34},
#   {'adult': False,
#    'gender': 2,
#    'id': 16857,
#    'known_for_department': 'Acting',
#    'name': '톰 에버렛 스콧',
#    'original_name': 'Tom Everett Scott',
#    'popularity': 8.413,
#    'profile_path': '/nVDihOvsSm7kmeyHLtAcEzrrSYC.jpg',
#    'cast_id': 334,
#    'character': 'David',
#    'credit_id': '57df4f8fc3a3681da00036eb',
#    'order': 35},
#   {'adult': False,
#    'gender': 2,
#    'id': 164208,
#    'known_for_department': 'Acting',
#    'name': 'Hemky Madera',
#    'original_name': 'Hemky Madera',
#    'popularity': 7.247,
#    'profile_path': '/net1kEEpSrr9QC9be6YRhLGuM0k.jpg',
#    'cast_id': 42,
#    'character': 'Jimmy',
#    'credit_id': '575d5453c3a36810a4004bbf',
#    'order': 36},
#   {'adult': False,
#    'gender': 1,
#    'id': 1584972,
#    'known_for_department': 'Acting',
#    'name': 'Zoë Hall',
#    'original_name': 'Zoë Hall',
#    'popularity': 1.41,
#    'profile_path': None,
#    'cast_id': 52,
#    'character': 'Chelsea',
#    'credit_id': '575d55219251415a0a004e46',
#    'order': 37},
#   {'adult': False,
#    'gender': 2,
#    'id': 167756,
#    'known_for_department': 'Acting',
#    'name': 'Dempsey Pappion',
#    'original_name': 'Dempsey Pappion',
#    'popularity': 1.453,
#    'profile_path': '/jPqHoYUzlo5MwZbvFUKi2XqNYaN.jpg',
#    'cast_id': 70,
#    'character': 'Charles',
#    'credit_id': '575d57099251414ed5001755',
#    'order': 38},
#   {'adult': False,
#    'gender': 0,
#    'id': 1503838,
#    'known_for_department': 'Acting',
#    'name': "Clifton 'Fou Fou' Eddie",
#    'original_name': "Clifton 'Fou Fou' Eddie",
#    'popularity': 0.72,
#    'profile_path': '/jIxkjRSTGvfnr06zVRHeOk3uDsb.jpg',
#    'cast_id': 424,
#    'character': "Seb's Drummer",
#    'credit_id': '64e31ea9b77d4b11434a0c88',
#    'order': 39},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226010,
#    'known_for_department': 'Acting',
#    'name': 'Cal Bennett',
#    'original_name': 'Cal Bennett',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 425,
#    'character': "Seb's Sax Player",
#    'credit_id': '64e31eceda9ef248f0fb99a0',
#    'order': 40},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226011,
#    'known_for_department': 'Acting',
#    'name': 'Nedra Wheeler',
#    'original_name': 'Nedra Wheeler',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 426,
#    'character': "Seb's Bassist",
#    'credit_id': '64e31ed7b77d4b1141fad6fc',
#    'order': 41},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226013,
#    'known_for_department': 'Acting',
#    'name': 'Javier Gonzalez',
#    'original_name': 'Javier Gonzalez',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 427,
#    'character': "Seb's Trumpeter",
#    'credit_id': '64e31ee8b77d4b113e0843a9',
#    'order': 42},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226014,
#    'known_for_department': 'Acting',
#    'name': 'Khirye Tyler',
#    'original_name': 'Khirye Tyler',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 428,
#    'character': "Seb's Pianst",
#    'credit_id': '64e31ef2da9ef248f180f21a',
#    'order': 43},
#   {'adult': True,
#    'gender': 1,
#    'id': 1795541,
#    'known_for_department': 'Acting',
#    'name': 'Briana Lee',
#    'original_name': 'Briana Lee',
#    'popularity': 4.583,
#    'profile_path': None,
#    'cast_id': 357,
#    'character': 'Echo Backup Singer',
#    'credit_id': '58efe38d92514125b1002091',
#    'order': 44},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226008,
#    'known_for_department': 'Acting',
#    'name': 'Shaylah J. Stevens',
#    'original_name': 'Shaylah J. Stevens',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 422,
#    'character': 'Echo Backup Singer',
#    'credit_id': '64e31e5b544c410138b435be',
#    'order': 45},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226007,
#    'known_for_department': 'Acting',
#    'name': 'Natalie Imani',
#    'original_name': 'Natalie Imani',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 421,
#    'character': 'Echo Backup Singer',
#    'credit_id': '64e31e5337109700ffbb3efb',
#    'order': 46},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226009,
#    'known_for_department': 'Acting',
#    'name': 'Camryn Ray Cavaliero',
#    'original_name': 'Camryn Ray Cavaliero',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 423,
#    'character': "Mia's Daughter",
#    'credit_id': '64e31e95b77d4b1141fad6d8',
#    'order': 47},
#   {'adult': False,
#    'gender': 1,
#    'id': 1585042,
#    'known_for_department': 'Acting',
#    'name': 'Sandra Rosko',
#    'original_name': 'Sandra Rosko',
#    'popularity': 2.201,
#    'profile_path': '/rYJ185ACbXGAsGbixXRe6i7t2hX.jpg',
#    'cast_id': 28,
#    'character': 'Dream Audience',
#    'credit_id': '575d52f19251414ed500162b',
#    'order': 48},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226016,
#    'known_for_department': 'Acting',
#    'name': 'Arthur Horowitz',
#    'original_name': 'Arthur Horowitz',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 429,
#    'character': 'Fantasy Baby',
#    'credit_id': '64e31efae19de90100e9d0fc',
#    'order': 49},
#   {'adult': False,
#    'gender': 1,
#    'id': 568656,
#    'known_for_department': 'Acting',
#    'name': 'Reshma Gajjar',
#    'original_name': 'Reshma Gajjar',
#    'popularity': 1.497,
#    'profile_path': '/jUNegvA6N7xlGYAZI9dZ2ftAj6i.jpg',
#    'cast_id': 344,
#    'character': 'Traffic Dancer - Girl #1',
#    'credit_id': '58efcac792514125a5000c03',
#    'order': 50},
#   {'adult': False,
#    'gender': 1,
#    'id': 1046202,
#    'known_for_department': 'Acting',
#    'name': 'Candice Coke',
#    'original_name': 'Candice Coke',
#    'popularity': 1.607,
#    'profile_path': '/aAZd7xXLIoqL1NZMxh5UasjiLwt.jpg',
#    'cast_id': 43,
#    'character': 'Traffic Dancer - Girl #2',
#    'credit_id': '575d545bc3a36873a300343b',
#    'order': 51},
#   {'adult': False,
#    'gender': 2,
#    'id': 1775884,
#    'known_for_department': 'Acting',
#    'name': 'Hunter Hamilton',
#    'original_name': 'Hunter Hamilton',
#    'popularity': 1.151,
#    'profile_path': None,
#    'cast_id': 345,
#    'character': 'Traffic Dancer - 1st Man',
#    'credit_id': '58efcd63c3a3686b3f000d2d',
#    'order': 52},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634327,
#    'known_for_department': 'Acting',
#    'name': 'Damian Gomez',
#    'original_name': 'Damian Gomez',
#    'popularity': 4.235,
#    'profile_path': '/oIeuu8YO4lC8aAYYaZ0lqvyu7mL.jpg',
#    'cast_id': 78,
#    'character': 'Traffic Dancer - 2nd Man',
#    'credit_id': '575d578cc3a36845160007d8',
#    'order': 53},
#   {'adult': False,
#    'gender': 1,
#    'id': 1795453,
#    'known_for_department': 'Acting',
#    'name': 'Amanda Balen',
#    'original_name': 'Amanda Balen',
#    'popularity': 3.209,
#    'profile_path': '/k1hncudIjPr81N3vetwGCmuCabK.jpg',
#    'cast_id': 346,
#    'character': 'Traffic Dancer - Conductor',
#    'credit_id': '58efcec0c3a3686b5d001014',
#    'order': 54},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226020,
#    'known_for_department': 'Acting',
#    'name': 'Lou Becker',
#    'original_name': 'Lou Becker',
#    'popularity': 0.088,
#    'profile_path': None,
#    'cast_id': 431,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e31f7965e0a20139ff70ba',
#    'order': 55},
#   {'adult': False,
#    'gender': 2,
#    'id': 2583127,
#    'known_for_department': 'Acting',
#    'name': 'Dominic Chaiduang',
#    'original_name': 'Dominic Chaiduang',
#    'popularity': 0.186,
#    'profile_path': None,
#    'cast_id': 384,
#    'character': 'Traffic Dancer',
#    'credit_id': '5e8119cfce4ddc0018734a59',
#    'order': 56},
#   {'adult': False,
#    'gender': 1,
#    'id': 1403025,
#    'known_for_department': 'Acting',
#    'name': 'Cindera Che',
#    'original_name': 'Cindera Che',
#    'popularity': 1.695,
#    'profile_path': '/w6gUBgOYeAg3khxr3fizH1VV89o.jpg',
#    'cast_id': 61,
#    'character': 'Traffic Dancer',
#    'credit_id': '575d56399251414ed500170f',
#    'order': 57},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634331,
#    'known_for_department': 'Acting',
#    'name': 'Chris Moss',
#    'original_name': 'Chris Moss',
#    'popularity': 2.288,
#    'profile_path': '/m95KDtXyiI3A303WVaGGY3MEzyl.jpg',
#    'cast_id': 83,
#    'character': 'Traffic Dancer',
#    'credit_id': '575d58709251412443001f05',
#    'order': 58},
#   {'adult': False,
#    'gender': 1,
#    'id': 1331887,
#    'known_for_department': 'Acting',
#    'name': 'Marissa Labog',
#    'original_name': 'Marissa Labog',
#    'popularity': 1.882,
#    'profile_path': '/77ORtHAM23gcnBuRflh5hQKZzX3.jpg',
#    'cast_id': 347,
#    'character': 'Traffic Dancer',
#    'credit_id': '58efd2b192514125cb00133f',
#    'order': 59},
#   {'adult': False,
#    'gender': 1,
#    'id': 963192,
#    'known_for_department': 'Acting',
#    'name': 'Tiffany Daniels',
#    'original_name': 'Tiffany Daniels',
#    'popularity': 3.108,
#    'profile_path': '/h65BnS8f2ccwk1eVTp3nXng7mOu.jpg',
#    'cast_id': 349,
#    'character': 'Traffic Dancer',
#    'credit_id': '58efd40692514125a900152d',
#    'order': 60},
#   {'adult': False,
#    'gender': 1,
#    'id': 1792487,
#    'known_for_department': 'Acting',
#    'name': 'Melinda Sullivan',
#    'original_name': 'Melinda Sullivan',
#    'popularity': 0.399,
#    'profile_path': '/jVctptNI0jgoytvBkm1VoVPPRi4.jpg',
#    'cast_id': 350,
#    'character': 'Traffic Dancer',
#    'credit_id': '58efd5d292514125b8001715',
#    'order': 61},
#   {'adult': False,
#    'gender': 1,
#    'id': 2126647,
#    'known_for_department': 'Acting',
#    'name': 'Stephanie Landwehr',
#    'original_name': 'Stephanie Landwehr',
#    'popularity': 0.626,
#    'profile_path': '/lm7nMnQxSWFsEpzDbWJ5Go9NMAt.jpg',
#    'cast_id': 383,
#    'character': 'Traffic Dancer',
#    'credit_id': '5b99124fc3a36802e200cdd1',
#    'order': 62},
#   {'adult': False,
#    'gender': 0,
#    'id': 1600207,
#    'known_for_department': 'Acting',
#    'name': 'Britt Stewart',
#    'original_name': 'Britt Stewart',
#    'popularity': 3.647,
#    'profile_path': '/9JxocLOhH8wOdqaGcrRn2wYGgMi.jpg',
#    'cast_id': 351,
#    'character': 'Traffic Dancer',
#    'credit_id': '58efd76192514125a5001659',
#    'order': 63},
#   {'adult': False,
#    'gender': 1,
#    'id': 1795524,
#    'known_for_department': 'Acting',
#    'name': 'Clarice Ordaz',
#    'original_name': 'Clarice Ordaz',
#    'popularity': 0.536,
#    'profile_path': '/wBe87dCDzDY102yMTXLNwuiylg2.jpg',
#    'cast_id': 352,
#    'character': 'Traffic Dancer',
#    'credit_id': '58efd987c3a3686b7f00169a',
#    'order': 64},
#   {'adult': False,
#    'gender': 2,
#    'id': 1748185,
#    'known_for_department': 'Acting',
#    'name': 'Nathan Prevost',
#    'original_name': 'Nathan Prevost',
#    'popularity': 1.684,
#    'profile_path': '/ptEmEF5uK1u40SnvrSjOCN9XWWV.jpg',
#    'cast_id': 353,
#    'character': 'Traffic Dancer',
#    'credit_id': '58efdcf3c3a3686b7f00190a',
#    'order': 65},
#   {'adult': False,
#    'gender': 0,
#    'id': 2775355,
#    'known_for_department': 'Crew',
#    'name': 'Mecca Vazie Andrews',
#    'original_name': 'Mecca Vazie Andrews',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 430,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e31f50da9ef248efed75d0',
#    'order': 66},
#   {'adult': False,
#    'gender': 2,
#    'id': 1028668,
#    'known_for_department': 'Acting',
#    'name': 'Scott Hislop',
#    'original_name': 'Scott Hislop',
#    'popularity': 1.395,
#    'profile_path': None,
#    'cast_id': 375,
#    'character': 'Hollywood Party Dancer - Creepy Guy',
#    'credit_id': '58f202929251412fc7008493',
#    'order': 67},
#   {'adult': False,
#    'gender': 2,
#    'id': 1516734,
#    'known_for_department': 'Acting',
#    'name': 'KC Monnie',
#    'original_name': 'KC Monnie',
#    'popularity': 2.062,
#    'profile_path': '/mSj3JATOM9AjHOw4VeGVrBbmk4A.jpg',
#    'cast_id': 67,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '575d56c99251412b0c003215',
#    'order': 68},
#   {'adult': False,
#    'gender': 1,
#    'id': 1003061,
#    'known_for_department': 'Acting',
#    'name': 'Krystal Ellsworth',
#    'original_name': 'Krystal Ellsworth',
#    'popularity': 4.991,
#    'profile_path': '/htDYbWlOUNF8N70iF44IZDOfk7w.jpg',
#    'cast_id': 374,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '58f20241c3a3682ee2007681',
#    'order': 69},
#   {'adult': False,
#    'gender': 1,
#    'id': 1778298,
#    'known_for_department': 'Acting',
#    'name': 'Sarah Mitchell',
#    'original_name': 'Sarah Mitchell',
#    'popularity': 0.35,
#    'profile_path': '/m4Lcuxsp0FgGH8kxTMJK741TDhP.jpg',
#    'cast_id': 373,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '58f20229c3a3682ea7007e1a',
#    'order': 70},
#   {'adult': False,
#    'gender': 2,
#    'id': 557784,
#    'known_for_department': 'Acting',
#    'name': 'Khasan Brailsford',
#    'original_name': 'Khasan Brailsford',
#    'popularity': 1.2,
#    'profile_path': '/9xP5pWLgmWoWwrN8gl7M4n4HKyB.jpg',
#    'cast_id': 386,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '5e8cd8a1a6a4c10013205188',
#    'order': 71},
#   {'adult': False,
#    'gender': 1,
#    'id': 1634311,
#    'known_for_department': 'Acting',
#    'name': 'Morgan Larson',
#    'original_name': 'Morgan Larson',
#    'popularity': 1.732,
#    'profile_path': '/2NsVx3Z8Ep0ZsLdsD5SAiBPnnrq.jpg',
#    'cast_id': 46,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '575d54bbc3a3685e2a0002f9',
#    'order': 72},
#   {'adult': False,
#    'gender': 1,
#    'id': 1752319,
#    'known_for_department': 'Acting',
#    'name': 'Becca Sweitzer',
#    'original_name': 'Becca Sweitzer',
#    'popularity': 2.132,
#    'profile_path': '/wW6Wtjg5OCOksrBwfGYxktY9yLc.jpg',
#    'cast_id': 340,
#    'character': 'Restaurant Dancer',
#    'credit_id': '58cbf4a99251415e44014438',
#    'order': 73},
#   {'adult': False,
#    'gender': 0,
#    'id': 1796610,
#    'known_for_department': 'Acting',
#    'name': 'Gakenia Muigai',
#    'original_name': 'Gakenia Muigai',
#    'popularity': 0.482,
#    'profile_path': None,
#    'cast_id': 372,
#    'character': 'Restaurant Dancer',
#    'credit_id': '58f201a9c3a3682ea7007d97',
#    'order': 74},
#   {'adult': False,
#    'gender': 2,
#    'id': 388569,
#    'known_for_department': 'Acting',
#    'name': 'Michael Stein',
#    'original_name': 'Michael Stein',
#    'popularity': 1.303,
#    'profile_path': '/ew6KjQhnVoYoLXztbEBLSEbzgQ.jpg',
#    'cast_id': 355,
#    'character': 'Restaurant Dancer',
#    'credit_id': '58efdfc6c3a3686b3f001ad9',
#    'order': 75},
#   {'adult': False,
#    'gender': 2,
#    'id': 665167,
#    'known_for_department': 'Acting',
#    'name': 'Mario Diaz',
#    'original_name': 'Mario Diaz',
#    'popularity': 0.629,
#    'profile_path': '/ytOusJHb2UKvICaR3gdaXLDAolJ.jpg',
#    'cast_id': 371,
#    'character': 'Restaurant Dancer',
#    'credit_id': '58f200f49251412fb10083fc',
#    'order': 76},
#   {'adult': False,
#    'gender': 0,
#    'id': 1516760,
#    'known_for_department': 'Acting',
#    'name': 'Julie Schmid',
#    'original_name': 'Julie Schmid',
#    'popularity': 0.314,
#    'profile_path': '/vmAz4CoiXapt2dMQBXHjjItDHJm.jpg',
#    'cast_id': 359,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efe6cb92514125cb00245d',
#    'order': 77},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226093,
#    'known_for_department': 'Acting',
#    'name': 'Samantha Abrantes',
#    'original_name': 'Samantha Abrantes',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 473,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e32788076ce843b5b8fcd2',
#    'order': 78},
#   {'adult': False,
#    'gender': 1,
#    'id': 1569519,
#    'known_for_department': 'Acting',
#    'name': 'Lexie Contursi',
#    'original_name': 'Lexie Contursi',
#    'popularity': 1.38,
#    'profile_path': '/gGUMFXbkkOicpueLOCVecbrxJU8.jpg',
#    'cast_id': 360,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efe82a9251412598002552',
#    'order': 79},
#   {'adult': False,
#    'gender': 0,
#    'id': 193127,
#    'known_for_department': 'Acting',
#    'name': 'Eartha Robinson',
#    'original_name': 'Eartha Robinson',
#    'popularity': 1.582,
#    'profile_path': '/uF6hUBsnX3MsZy0qXlelOkQ5R01.jpg',
#    'cast_id': 364,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efec6b92514125a9002c1d',
#    'order': 80},
#   {'adult': False,
#    'gender': 1,
#    'id': 151386,
#    'known_for_department': 'Acting',
#    'name': 'Sybil Azur',
#    'original_name': 'Sybil Azur',
#    'popularity': 2.546,
#    'profile_path': '/jyhPcSqQFThtnJSCeIis5aitvtq.jpg',
#    'cast_id': 361,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efe87092514125a5002532',
#    'order': 81},
#   {'adult': False,
#    'gender': 1,
#    'id': 1748116,
#    'known_for_department': 'Acting',
#    'name': 'Tara Nicole Hughes',
#    'original_name': 'Tara Nicole Hughes',
#    'popularity': 0.169,
#    'profile_path': '/rxextqelNmBO7pZumjfjv07FSiW.jpg',
#    'cast_id': 363,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efea2e92514125ad002826',
#    'order': 82},
#   {'adult': False,
#    'gender': 1,
#    'id': 1795557,
#    'known_for_department': 'Acting',
#    'name': 'Kayla Kalbfleisch',
#    'original_name': 'Kayla Kalbfleisch',
#    'popularity': 0.774,
#    'profile_path': '/bGv95ZBaP3uiJOCXsG09ntUa2bv.jpg',
#    'cast_id': 369,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58eff08692514125a900302c',
#    'order': 83},
#   {'adult': False,
#    'gender': 0,
#    'id': 557787,
#    'known_for_department': 'Acting',
#    'name': 'Martha Nichols',
#    'original_name': 'Martha Nichols',
#    'popularity': 0.462,
#    'profile_path': '/k5MpIl6LEe7btw7QAfOsUGQ4r3A.jpg',
#    'cast_id': 368,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efefb1c3a3686b7f002933',
#    'order': 84},
#   {'adult': False,
#    'gender': 2,
#    'id': 1494154,
#    'known_for_department': 'Acting',
#    'name': 'Anthony Marciona',
#    'original_name': 'Anthony Marciona',
#    'popularity': 1.407,
#    'profile_path': '/xXENYPnh4mCMAlAJ1agh10X9os8.jpg',
#    'cast_id': 79,
#    'character': 'Epilogue Dancer',
#    'credit_id': '575d57a19251412b0c003254',
#    'order': 85},
#   {'adult': False,
#    'gender': 2,
#    'id': 1795556,
#    'known_for_department': 'Acting',
#    'name': 'Bill Prudich',
#    'original_name': 'Bill Prudich',
#    'popularity': 0.774,
#    'profile_path': None,
#    'cast_id': 366,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efee65c3a3686b21002cca',
#    'order': 86},
#   {'adult': False,
#    'gender': 2,
#    'id': 1475074,
#    'known_for_department': 'Acting',
#    'name': 'Robert Roldan',
#    'original_name': 'Robert Roldan',
#    'popularity': 0.575,
#    'profile_path': '/nmsMzQ6eKoqGBF6z1IsAYRte32v.jpg',
#    'cast_id': 379,
#    'character': 'Epilogue Dancer',
#    'credit_id': '59922c119251417be3000172',
#    'order': 87},
#   {'adult': False,
#    'gender': 2,
#    'id': 1367476,
#    'known_for_department': 'Acting',
#    'name': 'Ryan Novak',
#    'original_name': 'Ryan Novak',
#    'popularity': 0.85,
#    'profile_path': None,
#    'cast_id': 367,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efee7bc3a3686b5d002c35',
#    'order': 88},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634486,
#    'known_for_department': 'Crew',
#    'name': 'Demian Boergadine',
#    'original_name': 'Demian Boergadine',
#    'popularity': 0.367,
#    'profile_path': '/nyfUZJi656sSeQAIid1Q0wC9H6k.jpg',
#    'cast_id': 362,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efe8c792514125a5002576',
#    'order': 89},
#   {'adult': False,
#    'gender': 2,
#    'id': 1775935,
#    'known_for_department': 'Acting',
#    'name': 'Gustavo Vargas',
#    'original_name': 'Gustavo Vargas',
#    'popularity': 0.826,
#    'profile_path': '/hnoyTgckJjl6bp8JPvVAIBc5fvv.jpg',
#    'cast_id': 358,
#    'character': 'Epilogue Dancer',
#    'credit_id': '58efe4ee92514125cb002283',
#    'order': 90},
#   {'adult': False,
#    'gender': 0,
#    'id': 1724205,
#    'known_for_department': 'Acting',
#    'name': 'Robert Haynes',
#    'original_name': 'Robert Haynes',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 335,
#    'character': 'Angry Neighbor',
#    'credit_id': '58567897c3a368258f046c9d',
#    'order': 91},
#   {'adult': False,
#    'gender': 0,
#    'id': 3330628,
#    'known_for_department': 'Acting',
#    'name': 'Doran Butler',
#    'original_name': 'Doran Butler',
#    'popularity': 0.018,
#    'profile_path': None,
#    'cast_id': 432,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e31f837ef38100b19c8cd0',
#    'order': 92},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226024,
#    'known_for_department': 'Acting',
#    'name': 'Matt Cady',
#    'original_name': 'Matt Cady',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 433,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e31f907ef3810121bb5c05',
#    'order': 93},
#   {'adult': False,
#    'gender': 0,
#    'id': 3986969,
#    'known_for_department': 'Sound',
#    'name': 'Carol Connors',
#    'original_name': 'Carol Connors',
#    'popularity': 1.378,
#    'profile_path': None,
#    'cast_id': 434,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e31ff7544c4100fe924fe1',
#    'order': 94},
#   {'adult': False,
#    'gender': 0,
#    'id': 3619365,
#    'known_for_department': 'Crew',
#    'name': 'Patrick Cook',
#    'original_name': 'Patrick Cook',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 435,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e3206f7ef3810104c6cac9',
#    'order': 95},
#   {'adult': False,
#    'gender': 0,
#    'id': 1398826,
#    'known_for_department': 'Acting',
#    'name': "Aaron 'Deuce' Cooke",
#    'original_name': "Aaron 'Deuce' Cooke",
#    'popularity': 1.037,
#    'profile_path': None,
#    'cast_id': 436,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e3208765e0a200c5ee89ce',
#    'order': 96},
#   {'adult': False,
#    'gender': 0,
#    'id': 1193101,
#    'known_for_department': 'Acting',
#    'name': 'Bubba Dean Rambo',
#    'original_name': 'Bubba Dean Rambo',
#    'popularity': 0.25,
#    'profile_path': '/62MjDPJQN8vDmjPX7ybPrKn14Ay.jpg',
#    'cast_id': 437,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e3209765e0a20139ff7157',
#    'order': 97},
#   {'adult': False,
#    'gender': 2,
#    'id': 188541,
#    'known_for_department': 'Acting',
#    'name': 'Nick Drago',
#    'original_name': 'Nick Drago',
#    'popularity': 1.505,
#    'profile_path': '/vMWL0yJFAp0oHpge6azZREJhIMo.jpg',
#    'cast_id': 438,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e320a4b77d4b1141fad7ef',
#    'order': 98},
#   {'adult': False,
#    'gender': 0,
#    'id': 3267962,
#    'known_for_department': 'Acting',
#    'name': 'Shaun Evaristo',
#    'original_name': 'Shaun Evaristo',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 439,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e320bae19de9011d5f4e0a',
#    'order': 99},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226032,
#    'known_for_department': 'Acting',
#    'name': 'Dana Fukagawa',
#    'original_name': 'Dana Fukagawa',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 440,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e320c77ef3810121bb5cac',
#    'order': 100},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226033,
#    'known_for_department': 'Acting',
#    'name': 'Daniel Gaymon',
#    'original_name': 'Daniel Gaymon',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 441,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e320d1371097011c550e6f',
#    'order': 101},
#   {'adult': False,
#    'gender': 0,
#    'id': 1763698,
#    'known_for_department': 'Crew',
#    'name': 'Liz Imperio',
#    'original_name': 'Liz Imperio',
#    'popularity': 0.006,
#    'profile_path': None,
#    'cast_id': 442,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e320da65e0a200e2efd39e',
#    'order': 102},
#   {'adult': False,
#    'gender': 0,
#    'id': 3573517,
#    'known_for_department': 'Acting',
#    'name': 'Casey Johansen',
#    'original_name': 'Casey Johansen',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 443,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e320f27ef38100ca0c934c',
#    'order': 103},
#   {'adult': False,
#    'gender': 2,
#    'id': 142606,
#    'known_for_department': 'Acting',
#    'name': 'Cris Judd',
#    'original_name': 'Cris Judd',
#    'popularity': 1.021,
#    'profile_path': '/jcTXeFk8arPo9XhxPc1MUw9F3rT.jpg',
#    'cast_id': 444,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e323b237109700ffbb4178',
#    'order': 104},
#   {'adult': False,
#    'gender': 0,
#    'id': 557776,
#    'known_for_department': 'Acting',
#    'name': 'Yoori Kim',
#    'original_name': 'Yoori Kim',
#    'popularity': 0.008,
#    'profile_path': None,
#    'cast_id': 445,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e3248a076ce843ba739109',
#    'order': 105},
#   {'adult': False,
#    'gender': 2,
#    'id': 4226059,
#    'known_for_department': 'Acting',
#    'name': 'Bradley M. Rapier',
#    'original_name': 'Bradley M. Rapier',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 446,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e324bd371097011c551049',
#    'order': 106},
#   {'adult': False,
#    'gender': 0,
#    'id': 3478483,
#    'known_for_department': 'Crew',
#    'name': 'Dana Wilson',
#    'original_name': 'Dana Wilson',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 447,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e324fc7ef381013ea3df9c',
#    'order': 107},
#   {'adult': False,
#    'gender': 0,
#    'id': 4061938,
#    'known_for_department': 'Acting',
#    'name': 'Terrance Yates',
#    'original_name': 'Terrance Yates',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 448,
#    'character': 'Traffic Dancer',
#    'credit_id': '64e3250d65e0a200e2efd5a5',
#    'order': 108},
#   {'adult': False,
#    'gender': 0,
#    'id': 557783,
#    'known_for_department': 'Acting',
#    'name': 'Tracy Shibata',
#    'original_name': 'Tracy Shibata',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 449,
#    'character': 'Hollywood Party Dancer - Girl #1',
#    'credit_id': '64e32521da9ef248efed780b',
#    'order': 109},
#   {'adult': False,
#    'gender': 1,
#    'id': 2271122,
#    'known_for_department': 'Acting',
#    'name': 'Dominique Domingo',
#    'original_name': 'Dominique Domingo',
#    'popularity': 1.736,
#    'profile_path': '/fjs2Vqs7NTW5FzqEG3tjo671yxW.jpg',
#    'cast_id': 450,
#    'character': 'Hollywood Party Dancer - Girl #2',
#    'credit_id': '64e3252c544c4100e16cc73f',
#    'order': 110},
#   {'adult': False,
#    'gender': 0,
#    'id': 2838234,
#    'known_for_department': 'Acting',
#    'name': 'Asiel Hardison',
#    'original_name': 'Asiel Hardison',
#    'popularity': 0.092,
#    'profile_path': '/eYSdGhrzRvAZd7m6Z5NpqvUGCO9.jpg',
#    'cast_id': 451,
#    'character': 'Hollywood Party Dancer - Agent #1',
#    'credit_id': '64e3253d65e0a200c5ee8b9f',
#    'order': 111},
#   {'adult': False,
#    'gender': 2,
#    'id': 3328756,
#    'known_for_department': 'Acting',
#    'name': 'Corey Anderson',
#    'original_name': 'Corey Anderson',
#    'popularity': 0.067,
#    'profile_path': None,
#    'cast_id': 452,
#    'character': 'Hollywood Party Dancer - Agent #2',
#    'credit_id': '64e3255865e0a20139ff7359',
#    'order': 112},
#   {'adult': False,
#    'gender': 2,
#    'id': 1752324,
#    'known_for_department': 'Acting',
#    'name': 'Nick Baga',
#    'original_name': 'Nick Baga',
#    'popularity': 1.184,
#    'profile_path': '/mOZBa0zodfqMqzvQ62kSOIMQUv.jpg',
#    'cast_id': 453,
#    'character': 'Hollywood Party Dancer - Agent #3',
#    'credit_id': '64e3256a37109700ffbb423f',
#    'order': 113},
#   {'adult': False,
#    'gender': 0,
#    'id': 1600201,
#    'known_for_department': 'Acting',
#    'name': 'Leah Adler',
#    'original_name': 'Leah Adler',
#    'popularity': 0.055,
#    'profile_path': None,
#    'cast_id': 454,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e3257f65e0a2011cb0d191',
#    'order': 114},
#   {'adult': False,
#    'gender': 0,
#    'id': 3782469,
#    'known_for_department': 'Acting',
#    'name': 'Noel Bajandas',
#    'original_name': 'Noel Bajandas',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 455,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e325887ef3810104c6cd4e',
#    'order': 115},
#   {'adult': False,
#    'gender': 0,
#    'id': 2291223,
#    'known_for_department': 'Acting',
#    'name': 'Denzel Chisolm',
#    'original_name': 'Denzel Chisolm',
#    'popularity': 0.172,
#    'profile_path': None,
#    'cast_id': 456,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e325a17ef38100b19c8f6b',
#    'order': 116},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226068,
#    'known_for_department': 'Acting',
#    'name': 'Montana Efaw',
#    'original_name': 'Montana Efaw',
#    'popularity': 0.151,
#    'profile_path': '/agCQ06geYu5KvoaGUrvngMbOJz4.jpg',
#    'cast_id': 457,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e325b765e0a200e2efd637',
#    'order': 117},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226072,
#    'known_for_department': 'Acting',
#    'name': 'Natalie Gilmore',
#    'original_name': 'Natalie Gilmore',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 458,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e325d7076ce843ba7391d1',
#    'order': 118},
#   {'adult': False,
#    'gender': 2,
#    'id': 557777,
#    'known_for_department': 'Acting',
#    'name': 'Shannon Holtzapffel',
#    'original_name': 'Shannon Holtzapffel',
#    'popularity': 0.511,
#    'profile_path': '/nmIRemt96xTQWr2B1Clpk8aNDkB.jpg',
#    'cast_id': 459,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e325e1b77d4b113e0846d0',
#    'order': 119},
#   {'adult': False,
#    'gender': 1,
#    'id': 2057152,
#    'known_for_department': 'Acting',
#    'name': 'Galen Hooks',
#    'original_name': 'Galen Hooks',
#    'popularity': 1.103,
#    'profile_path': '/pHCa12C16fKYhUwELLLYetivXpS.jpg',
#    'cast_id': 460,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e325ed7ef38100ca0c95bf',
#    'order': 120},
#   {'adult': False,
#    'gender': 2,
#    'id': 1290608,
#    'known_for_department': 'Acting',
#    'name': 'Jeremy Hudson',
#    'original_name': 'Jeremy Hudson',
#    'popularity': 1.757,
#    'profile_path': '/9wekDilA9uusZbOhSDOxXGK1y8f.jpg',
#    'cast_id': 461,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e3261c37109700ffbb42c0',
#    'order': 121},
#   {'adult': False,
#    'gender': 0,
#    'id': 4043303,
#    'known_for_department': 'Acting',
#    'name': 'George Lawrence Jr.',
#    'original_name': 'George Lawrence Jr.',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 462,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e3262db77d4b11401bd21e',
#    'order': 122},
#   {'adult': False,
#    'gender': 2,
#    'id': 1600205,
#    'known_for_department': 'Acting',
#    'name': 'Scott Myrick',
#    'original_name': 'Scott Myrick',
#    'popularity': 1.576,
#    'profile_path': '/sORXPcKRW9W0f9TPGyCQqf6g84D.jpg',
#    'cast_id': 463,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e32640076ce843b8d4ddb8',
#    'order': 123},
#   {'adult': False,
#    'gender': 0,
#    'id': 1600206,
#    'known_for_department': 'Acting',
#    'name': 'Cassidy Noblett',
#    'original_name': 'Cassidy Noblett',
#    'popularity': 0.137,
#    'profile_path': None,
#    'cast_id': 464,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e3264a544c4100ac3cec35',
#    'order': 124},
#   {'adult': False,
#    'gender': 0,
#    'id': 2291260,
#    'known_for_department': 'Acting',
#    'name': 'Brittany Parks',
#    'original_name': 'Brittany Parks',
#    'popularity': 0.571,
#    'profile_path': None,
#    'cast_id': 465,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e32673076ce843b74dc712',
#    'order': 125},
#   {'adult': False,
#    'gender': 2,
#    'id': 2813365,
#    'known_for_department': 'Acting',
#    'name': 'Víctor Rojas',
#    'original_name': 'Víctor Rojas',
#    'popularity': 0.717,
#    'profile_path': '/jFsVOq8GySgfC55H0SUgA0XKfGp.jpg',
#    'cast_id': 466,
#    'character': 'Hollywood Party Dancer',
#    'credit_id': '64e326d0b77d4b11401bd275',
#    'order': 126},
#   {'adult': False,
#    'gender': 2,
#    'id': 1398069,
#    'known_for_department': 'Acting',
#    'name': 'Tony Bellissimo',
#    'original_name': 'Tony Bellissimo',
#    'popularity': 0.645,
#    'profile_path': '/usxy97IHYywasyS9kRVK6iBPhk2.jpg',
#    'cast_id': 467,
#    'character': 'Echo Dancer',
#    'credit_id': '64e326f1da9ef248f36505be',
#    'order': 127},
#   {'adult': False,
#    'gender': 0,
#    'id': 2432592,
#    'known_for_department': 'Acting',
#    'name': 'Ryan Ramirez',
#    'original_name': 'Ryan Ramirez',
#    'popularity': 1.029,
#    'profile_path': None,
#    'cast_id': 468,
#    'character': 'Echo Dancer',
#    'credit_id': '64e326ffb77d4b114261083a',
#    'order': 128},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226085,
#    'known_for_department': 'Acting',
#    'name': 'Catalina Cat Rendic',
#    'original_name': 'Catalina Cat Rendic',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 469,
#    'character': 'Echo Dancer',
#    'credit_id': '64e3271c37109700e22a945b',
#    'order': 129},
#   {'adult': False,
#    'gender': 0,
#    'id': 2057166,
#    'known_for_department': 'Acting',
#    'name': 'Bryan Tanaka',
#    'original_name': 'Bryan Tanaka',
#    'popularity': 0.055,
#    'profile_path': None,
#    'cast_id': 470,
#    'character': 'Echo Dancer',
#    'credit_id': '64e32725544c4100ac3cecc1',
#    'order': 130},
#   {'adult': False,
#    'gender': 1,
#    'id': 3792345,
#    'known_for_department': 'Acting',
#    'name': 'Ava Bernstine-Mitchell',
#    'original_name': 'Ava Bernstine-Mitchell',
#    'popularity': 0.28,
#    'profile_path': None,
#    'cast_id': 471,
#    'character': 'Restaurant Dancer',
#    'credit_id': '64e327337ef3810121bb5ff7',
#    'order': 131},
#   {'adult': False,
#    'gender': 0,
#    'id': 2611624,
#    'known_for_department': 'Acting',
#    'name': 'Quinn Lipton',
#    'original_name': 'Quinn Lipton',
#    'popularity': 0.087,
#    'profile_path': None,
#    'cast_id': 472,
#    'character': 'Restaurant Dancer',
#    'credit_id': '64e3276dda9ef248f365060d',
#    'order': 132},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226094,
#    'known_for_department': 'Acting',
#    'name': 'Monie Adamson',
#    'original_name': 'Monie Adamson',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 474,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e32792da9ef248f47876ba',
#    'order': 133},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226097,
#    'known_for_department': 'Acting',
#    'name': 'Matthew Aylward',
#    'original_name': 'Matthew Aylward',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 475,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e3279b65e0a200ffbdf577',
#    'order': 134},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226098,
#    'known_for_department': 'Acting',
#    'name': 'McKenzie Anderson',
#    'original_name': 'McKenzie Anderson',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 476,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e327a77ef381013ea3e116',
#    'order': 135},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226101,
#    'known_for_department': 'Acting',
#    'name': 'Pamela Chu',
#    'original_name': 'Pamela Chu',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 477,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e327c87ef3810121bb6061',
#    'order': 136},
#   {'adult': False,
#    'gender': 0,
#    'id': 2522448,
#    'known_for_department': 'Acting',
#    'name': 'Mallauri Esquibel',
#    'original_name': 'Mallauri Esquibel',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 478,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e327d965e0a20139ff749c',
#    'order': 137},
#   {'adult': False,
#    'gender': 2,
#    'id': 1753706,
#    'known_for_department': 'Acting',
#    'name': 'Michael Higgins',
#    'original_name': 'Michael Higgins',
#    'popularity': 1.264,
#    'profile_path': None,
#    'cast_id': 479,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e327ed7ef381013ea3e13c',
#    'order': 138},
#   {'adult': False,
#    'gender': 0,
#    'id': 3175032,
#    'known_for_department': 'Acting',
#    'name': 'Chris Jarosz',
#    'original_name': 'Chris Jarosz',
#    'popularity': 0.028,
#    'profile_path': None,
#    'cast_id': 480,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e3280fb77d4b113e0847fc',
#    'order': 139},
#   {'adult': False,
#    'gender': 0,
#    'id': 4226112,
#    'known_for_department': 'Acting',
#    'name': 'Matthew Kazmierczak',
#    'original_name': 'Matthew Kazmierczak',
#    'popularity': 0.001,
#    'profile_path': None,
#    'cast_id': 481,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e3282565e0a200e2efd7f2',
#    'order': 140},
#   {'adult': False,
#    'gender': 0,
#    'id': 1091553,
#    'known_for_department': 'Acting',
#    'name': 'Paul Kirkland',
#    'original_name': 'Paul Kirkland',
#    'popularity': 0.691,
#    'profile_path': None,
#    'cast_id': 482,
#    'character': 'Epilogue Dancer',
#    'credit_id': '64e328317ef38100ca0c9757',
#    'order': 141},
#   {'adult': False,
#    'gender': 0,
#    'id': 1888053,
#    'known_for_department': 'Crew',
#    'name': 'Megan Lawson',
#    'original_name': 'Megan Lawson',
#    'popularity': 0.001,
# ...
#    'department': 'Production',
#    'job': 'Executive In Charge Of Post Production'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634513,
#    'known_for_department': 'Production',
#    'name': 'Curtis A. Miller',
#    'original_name': 'Curtis A. Miller',
#    'popularity': 0.07,
#    'profile_path': None,
#    'credit_id': '575d7b4a9251415a0a005781',
#    'department': 'Production',
#    'job': 'Executive In Charge Of Production'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1329113,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Lynda Foote',
#    'original_name': 'Lynda Foote',
#    'popularity': 1.495,
#    'profile_path': None,
#    'credit_id': '575d7484c3a3684516000ed0',
#    'department': 'Costume & Make-Up',
#    'job': 'Costume Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1547662,
#    'known_for_department': 'Editing',
#    'name': 'John To',
#    'original_name': 'John To',
#    'popularity': 0.154,
#    'profile_path': None,
#    'credit_id': '575d75ccc3a3681351002a0e',
#    'department': 'Editing',
#    'job': 'First Assistant Editor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1435661,
#    'known_for_department': 'Crew',
#    'name': 'Marty Osborne',
#    'original_name': 'Marty Osborne',
#    'popularity': 0.072,
#    'profile_path': None,
#    'credit_id': '575d78ab925141536d000773',
#    'department': 'Crew',
#    'job': 'Driver'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634491,
#    'known_for_department': 'Production',
#    'name': 'Ami Cohen',
#    'original_name': 'Ami Cohen',
#    'popularity': 0.038,
#    'profile_path': None,
#    'credit_id': '575d7989925141189e001328',
#    'department': 'Crew',
#    'job': 'Department Administrator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634512,
#    'known_for_department': 'Crew',
#    'name': 'Robert M. Melnik',
#    'original_name': 'Robert M. Melnik',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7b319251412443002697',
#    'department': 'Crew',
#    'job': 'Executive in Charge of Finance'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1176697,
#    'known_for_department': 'Directing',
#    'name': 'Jacob Whitley',
#    'original_name': 'Jacob Whitley',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7d429251415dd2003450',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1377139,
#    'known_for_department': 'Art',
#    'name': 'Steve Beimler',
#    'original_name': 'Steve Beimler',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7909925141189e0012fd',
#    'department': 'Art',
#    'job': 'Location Scout'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634505,
#    'known_for_department': 'Crew',
#    'name': 'Ossey James',
#    'original_name': 'Ossey James',
#    'popularity': 0.333,
#    'profile_path': '/oh0tI9c9PEc0ueTWj4qU8Q3iY1E.jpg',
#    'credit_id': '575d7a94c3a3684516001047',
#    'department': 'Crew',
#    'job': 'Stand In'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1617224,
#    'known_for_department': 'Camera',
#    'name': 'Owen Patry',
#    'original_name': 'Owen Patry',
#    'popularity': 0.039,
#    'profile_path': None,
#    'credit_id': '575d7b76c3a36873a3003e33',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634518,
#    'known_for_department': 'Art',
#    'name': 'Michael Riley',
#    'original_name': 'Michael Riley',
#    'popularity': 0.001,
#    'profile_path': '/tFe7WxdDON3gt4riylUptYpz0TA.jpg',
#    'credit_id': '575d7c789251415dd2003426',
#    'department': 'Crew',
#    'job': 'Title Graphics'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634519,
#    'known_for_department': 'Crew',
#    'name': 'Ross Risley',
#    'original_name': 'Ross Risley',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7c84c3a36836e500000e',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634522,
#    'known_for_department': 'Crew',
#    'name': 'Danny Valle',
#    'original_name': 'Danny Valle',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7d10c3a36813180025bb',
#    'department': 'Crew',
#    'job': 'Other'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634486,
#    'known_for_department': 'Crew',
#    'name': 'Demian Boergadine',
#    'original_name': 'Demian Boergadine',
#    'popularity': 0.367,
#    'profile_path': '/nyfUZJi656sSeQAIid1Q0wC9H6k.jpg',
#    'credit_id': '575d7940925141536d00078f',
#    'department': 'Crew',
#    'job': 'Other'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634521,
#    'known_for_department': 'Crew',
#    'name': 'Theresa Snider',
#    'original_name': 'Theresa Snider',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7cbdc3a3683791000005',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1463846,
#    'known_for_department': 'Crew',
#    'name': 'John F. Teeple',
#    'original_name': 'John F. Teeple',
#    'popularity': 0.057,
#    'profile_path': None,
#    'credit_id': '575d78b89251412b0c0039cc',
#    'department': 'Crew',
#    'job': 'Driver'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634494,
#    'known_for_department': 'Directing',
#    'name': 'Richard Lee Dalton',
#    'original_name': 'Richard Lee Dalton',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d79b5c3a3681318002510',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634525,
#    'known_for_department': 'Crew',
#    'name': 'Tyler John Young',
#    'original_name': 'Tyler John Young',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7d6ec3a3681351002bf8',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634517,
#    'known_for_department': 'Production',
#    'name': 'Carrie Prince',
#    'original_name': 'Carrie Prince',
#    'popularity': 0.518,
#    'profile_path': None,
#    'credit_id': '575d7be29251412b0c003a86',
#    'department': 'Production',
#    'job': 'Other'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634483,
#    'known_for_department': 'Production',
#    'name': 'Malcolm Arias',
#    'original_name': 'Malcolm Arias',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d78fe9251412b0c0039e1',
#    'department': 'Production',
#    'job': 'Finance'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634499,
#    'known_for_department': 'Production',
#    'name': 'Stephanie M. Flores',
#    'original_name': 'Stephanie M. Flores',
#    'popularity': 0.132,
#    'profile_path': None,
#    'credit_id': '575d7a1f9251414a820045cd',
#    'department': 'Production',
#    'job': 'Other'},
#   {'adult': False,
#    'gender': 0,
#    'id': 95848,
#    'known_for_department': 'Production',
#    'name': 'Robert Foulkes',
#    'original_name': 'Robert Foulkes',
#    'popularity': 0.168,
#    'profile_path': None,
#    'credit_id': '575d7a3a9251414a820045d3',
#    'department': 'Production',
#    'job': 'Location Manager'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634501,
#    'known_for_department': 'Production',
#    'name': 'Michael A. Fry',
#    'original_name': 'Michael A. Fry',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7a53c3a368451600102d',
#    'department': 'Production',
#    'job': 'Other'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634503,
#    'known_for_department': 'Crew',
#    'name': 'Hadeel Hadidi',
#    'original_name': 'Hadeel Hadidi',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7a749251412b0c003a45',
#    'department': 'Crew',
#    'job': "Actor's Assistant"},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634497,
#    'known_for_department': 'Crew',
#    'name': 'Jessi Eichberger',
#    'original_name': 'Jessi Eichberger',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d79f7925141189e001348',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1235227,
#    'known_for_department': 'Production',
#    'name': 'Scott Trimble',
#    'original_name': 'Scott Trimble',
#    'popularity': 0.869,
#    'profile_path': '/bG3HXEa7rWVAGr0tvLXM8RTkMX0.jpg',
#    'credit_id': '575d7cd7925141536d00083e',
#    'department': 'Art',
#    'job': 'Location Scout'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1582399,
#    'known_for_department': 'Production',
#    'name': 'Timothy Scott Ralston',
#    'original_name': 'Timothy Scott Ralston',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7c429251415a0a0057bc',
#    'department': 'Production',
#    'job': 'Executive In Charge Of Post Production'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634527,
#    'known_for_department': 'Crew',
#    'name': 'Kate Gray',
#    'original_name': 'Kate Gray',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7d7ec3a36831a4004348',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1397737,
#    'known_for_department': 'Crew',
#    'name': 'Geno Hart',
#    'original_name': 'Geno Hart',
#    'popularity': 2.975,
#    'profile_path': None,
#    'credit_id': '575d78a19251415403000787',
#    'department': 'Crew',
#    'job': 'Transportation Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634506,
#    'known_for_department': 'Production',
#    'name': 'Sherry Kecskes',
#    'original_name': 'Sherry Kecskes',
#    'popularity': 0.448,
#    'profile_path': None,
#    'credit_id': '575d7aa69251415dd20033db',
#    'department': 'Production',
#    'job': 'Finance'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634508,
#    'known_for_department': 'Crew',
#    'name': 'Laurent Marchand',
#    'original_name': 'Laurent Marchand',
#    'popularity': 0.046,
#    'profile_path': None,
#    'credit_id': '575d7ae8c3a3681351002b70',
#    'department': 'Crew',
#    'job': 'Other'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1370916,
#    'known_for_department': 'Directing',
#    'name': 'Lyn Matsuda Norton',
#    'original_name': 'Lyn Matsuda Norton',
#    'popularity': 0.398,
#    'profile_path': None,
#    'credit_id': '575d7af9c3a3681351002b79',
#    'department': 'Directing',
#    'job': 'Script Supervisor'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1634514,
#    'known_for_department': 'Crew',
#    'name': 'Carly Olsson',
#    'original_name': 'Carly Olsson',
#    'popularity': 0.001,
#    'profile_path': None,
#    'credit_id': '575d7b66925141536d0007fb',
#    'department': 'Crew',
#    'job': 'Production Office Assistant'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1253687,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Jo Kissack Folsom',
#    'original_name': 'Jo Kissack Folsom',
#    'popularity': 1.33,
#    'profile_path': None,
#    'credit_id': '57ae405b9251411c5c000435',
#    'department': 'Costume & Make-Up',
#    'job': 'Assistant Costume Designer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1419631,
#    'known_for_department': 'Sound',
#    'name': 'Justin Hurwitz',
#    'original_name': 'Justin Hurwitz',
#    'popularity': 1.044,
#    'profile_path': '/4a03MPhWE8u0NGJF9wt0wbBcFWn.jpg',
#    'credit_id': '57ae3dc5c3a3686828000401',
#    'department': 'Sound',
#    'job': 'Original Music Composer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 969171,
#    'known_for_department': 'Camera',
#    'name': 'Linus Sandgren',
#    'original_name': 'Linus Sandgren',
#    'popularity': 1.314,
#    'profile_path': '/ihiOYVxA7XwgSJva5C7HZuGopY5.jpg',
#    'credit_id': '57ae3cd6c3a3686833000328',
#    'department': 'Camera',
#    'job': 'Director of Photography'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1671065,
#    'known_for_department': 'Production',
#    'name': 'Kerri Smeltzer',
#    'original_name': 'Kerri Smeltzer',
#    'popularity': 0.325,
#    'profile_path': None,
#    'credit_id': '57c1bc99c3a36865ac0052f2',
#    'department': 'Production',
#    'job': 'Production Coordinator'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1638298,
#    'known_for_department': 'Production',
#    'name': 'Fred Berger',
#    'original_name': 'Fred Berger',
#    'popularity': 4.819,
#    'profile_path': '/7ZnEZ8DVEBtpuNLXTNMj9T4ERb9.jpg',
#    'credit_id': '586d7740925141431b0019a7',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1710767,
#    'known_for_department': 'Crew',
#    'name': 'Mandy Moore',
#    'original_name': 'Mandy Moore',
#    'popularity': 0.875,
#    'profile_path': '/kSwf5JCgwJlsySyDTkDvuBKR8F.jpg',
#    'credit_id': '58e36a1692514179de00f4d9',
#    'department': 'Crew',
#    'job': 'Choreographer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1419631,
#    'known_for_department': 'Sound',
#    'name': 'Justin Hurwitz',
#    'original_name': 'Justin Hurwitz',
#    'popularity': 1.044,
#    'profile_path': '/4a03MPhWE8u0NGJF9wt0wbBcFWn.jpg',
#    'credit_id': '6430daf0b076e50097f63d63',
#    'department': 'Sound',
#    'job': 'Songs'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1456906,
#    'known_for_department': 'Writing',
#    'name': 'Justin Paul',
#    'original_name': 'Justin Paul',
#    'popularity': 0.397,
#    'profile_path': '/s6ghklJOU6U4gO1zMRgine5a4VU.jpg',
#    'credit_id': '6430db0495c0af00d5cb7a8f',
#    'department': 'Writing',
#    'job': 'Lyricist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 136495,
#    'known_for_department': 'Directing',
#    'name': '데이미언 셔젤',
#    'original_name': 'Damien Chazelle',
#    'popularity': 10.957,
#    'profile_path': '/14kRZ3XxNMyBv717YQSXr3wCucy.jpg',
#    'credit_id': '6430db15e92d830097c5328d',
#    'department': 'Writing',
#    'job': 'Lyricist'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1777376,
#    'known_for_department': 'Sound',
#    'name': 'Benj Pasek',
#    'original_name': 'Benj Pasek',
#    'popularity': 4.18,
#    'profile_path': '/rkgQaNJIOkDwlcrolW0BkTLRm7q.jpg',
#    'credit_id': '6430dafa1dbc8800b61037da',
#    'department': 'Writing',
#    'job': 'Lyricist'},
#   {'adult': False,
#    'gender': 1,
#    'id': 1367494,
#    'known_for_department': 'Sound',
#    'name': 'Ai-Ling Lee',
#    'original_name': 'Ai-Ling Lee',
#    'popularity': 0.684,
#    'profile_path': None,
#    'credit_id': '5a25c69c925141032c0e408d',
#    'department': 'Sound',
#    'job': 'Supervising Sound Editor'},
#   {'adult': False,
#    'gender': 2,
#    'id': 5371,
#    'known_for_department': 'Production',
#    'name': 'Gary Gilbert',
#    'original_name': 'Gary Gilbert',
#    'popularity': 1.127,
#    'profile_path': '/eLIK6NzpXfPh4e5onZdFtfPXQCD.jpg',
#    'credit_id': '5a3cca72c3a36814a80b7043',
#    'department': 'Production',
#    'job': 'Producer'},
#   {'adult': False,
#    'gender': 2,
#    'id': 9654,
#    'known_for_department': 'Crew',
#    'name': 'Charles Croughwell',
#    'original_name': 'Charles Croughwell',
#    'popularity': 1.365,
#    'profile_path': '/b07qb8NrxvKqO62oz0VQA8iYsK4.jpg',
#    'credit_id': '648e6c66559d2200e2065b5a',
#    'department': 'Crew',
#    'job': 'Stunt Coordinator'},
#   {'adult': False,
#    'gender': 0,
#    'id': 1574780,
#    'known_for_department': 'Costume & Make-Up',
#    'name': 'Chad R. Davis',
#    'original_name': 'Chad R. Davis',
#    'popularity': 0.275,
#    'profile_path': None,
#    'credit_id': '64c65024cadb6b01440dea8f',
#    'department': 'Costume & Make-Up',
#    'job': 'On Set Dresser'},
#   {'adult': False,
#    'gender': 2,
#    'id': 136495,
#    'known_for_department': 'Directing',
#    'name': '데이미언 셔젤',
#    'original_name': 'Damien Chazelle',
#    'popularity': 10.957,
#    'profile_path': '/14kRZ3XxNMyBv717YQSXr3wCucy.jpg',
#    'credit_id': '5e85d33f98f1f10012ab104b',
#    'department': 'Directing',
#    'job': 'Director'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634415,
#    'known_for_department': 'Art',
#    'name': 'Matthew Cavaliero',
#    'original_name': 'Matthew Cavaliero',
#    'popularity': 0.868,
#    'profile_path': None,
#    'credit_id': '5fdccd477776f0003f3333d7',
#    'department': 'Art',
#    'job': 'Property Master'},
#   {'adult': False,
#    'gender': 2,
#    'id': 1634424,
#    'known_for_department': 'Art',
#    'name': 'John Youngblood',
#    'original_name': 'John Youngblood',
#    'popularity': 0.052,
#    'profile_path': None,
#    'credit_id': '5fdd2d3fd70594003c28100c',
#    'department': 'Art',
#    'job': 'Assistant Property Master'}]}

# %% [markdown]
# ## 통합

# %%
import requests
from odmantic import AIOEngine, Model
from motor.motor_asyncio import AsyncIOMotorClient
from typing import Optional, List
import asyncio

# Odmantic 모델 정의
class Movie(Model):
    movie_id: int
    title: str
    original_title: Optional[str] = None
    poster_path: Optional[str] = None
    language: str
    genre_ids: List[int]
    popularity: float
    release_date: Optional[str] = None
    cast: Optional[List[dict]] = None

# 단일 영화의 캐스트 정보 가져오기
async def fetch_cast(movie_id: int, headers: dict) -> List[dict]:
    credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?language=ko-KR"
    response = await asyncio.to_thread(requests.get, credits_url, headers=headers)
    credits_data = response.json()
    return [
        {"cast_id": cast.get("id"), "name": cast.get("name")}
        for cast in credits_data.get("cast", [])[:8]
    ]  # 상위 8개만 반환

# 단일 영화 데이터를 처리하고 저장할 객체 생성
async def process_movie(item, headers, engine):
    movie_id = item["id"]
    cast_info = await fetch_cast(movie_id, headers)
    movie = Movie(
        movie_id=movie_id,
        title=item.get("title") or item.get("name"),
        original_title=item.get("original_title") or item.get("original_name"),
        poster_path=item.get("poster_path"),
        language=item.get("original_language"),
        genre_ids=item.get("genre_ids", []),
        popularity=item.get("popularity", 0.0),
        release_date=item.get("release_date") or item.get("first_air_date"),
        cast=cast_info,
    )
    await engine.save(movie)

# 전체 데이터 처리
async def fetch_and_store_movies():
    search_query = "청설"
    search_url = f"https://api.themoviedb.org/3/search/movie?query={search_query}&include_adult=false&language=ko-KR&page=1"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw",
    }
    response = requests.get(search_url, headers=headers)
    data = response.json()

    client = AsyncIOMotorClient("mongodb://user:team3@localhost:27017/")
    engine = AIOEngine(client=client, database="movies_db")

    if "results" in data:
        tasks = [
            process_movie(item, headers, engine)
            for item in data["results"]
        ]
        await asyncio.gather(*tasks)  # 병렬 처리
        print("필터링된 데이터와 캐스트 정보가 성공적으로 저장되었습니다!")
    else:
        print("API 응답에 'results' 키가 없습니다.")

# %%
import nest_asyncio
import asyncio

# Jupyter Notebook에서 nest_asyncio 적용
nest_asyncio.apply()

# 비동기 실행
if __name__ == "__main__":
    asyncio.run(fetch_and_store_movies())
# Out:
# 필터링된 데이터와 캐스트 및 감독 정보가 성공적으로 저장되었습니다!

# %%
import requests
from odmantic import AIOEngine, Model
from motor.motor_asyncio import AsyncIOMotorClient
from typing import Optional, List

# Odmantic 모델 정의
class Movie(Model):
    movie_id: int
    title: str
    original_title: Optional[str] = None
    poster_path: Optional[str] = None
    language: str
    genre_ids: List[int]
    popularity: float
    release_date: Optional[str] = None
    cast: Optional[List[dict]] = None
    director: Optional[dict] = None  # Director 정보 추가

# 단일 영화의 캐스트 및 감독 정보 가져오기
async def fetch_credit(movie_id: int, headers: dict) -> (List[dict], Optional[dict]):
    credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?language=ko-KR"
    response = await asyncio.to_thread(requests.get, credits_url, headers=headers)
    credits_data = response.json()

    # 캐스트 정보 상위 8개
    cast = [
        {"cast_id": cast.get("id"), "name": cast.get("name")}
        for cast in credits_data.get("cast", [])[:8]
    ]

    # 감독 정보 필터링
    director = next(
        (
            {"id": crew["id"], "name": crew["name"]}
            for crew in credits_data.get("crew", [])
            if crew.get("job") == "Director"
        ),
        None,
    )

    return cast, director

# 단일 영화 데이터를 처리하고 저장할 객체 생성
async def process_movie(item, headers, engine):
    movie_id = item["id"]
    cast_info, director_info = await fetch_credit(movie_id, headers)

    movie = Movie(
        movie_id=movie_id,
        title=item.get("title") or item.get("name"),
        original_title=item.get("original_title") or item.get("original_name"),
        poster_path=item.get("poster_path"),
        language=item.get("original_language"),
        genre_ids=item.get("genre_ids", []),
        popularity=item.get("popularity", 0.0),
        release_date=item.get("release_date") or item.get("first_air_date"),
        cast=cast_info,
        director=director_info,
    )
    await engine.save(movie)

# 전체 데이터 처리
async def fetch_and_store_movies():
    search_query = "La La Land"
    search_url = f"https://api.themoviedb.org/3/search/movie?query={search_query}&include_adult=false&language=ko-KO&page=1"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw",
    }
    response = requests.get(search_url, headers=headers)
    data = response.json()

    client = AsyncIOMotorClient("mongodb://user:team3@localhost:27017/")
    engine = AIOEngine(client=client, database="movies_db")

    if "results" in data:
        tasks = [
            process_movie(item, headers, engine)
            for item in data["results"]
        ]
        await asyncio.gather(*tasks)  # 병렬 처리
        print("필터링된 데이터와 캐스트 및 감독 정보가 성공적으로 저장되었습니다!")
    else:
        print("API 응답에 'results' 키가 없습니다.")

# %%
import requests

url = "https://api.themoviedb.org/3/search/movie?query=La%20La%20Land&include_adult=false&language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/qJeU7KM4nT2C1WpOrwPcSDGFUWE.jpg',
#    'genre_ids': [35, 18, 10749, 10402],
#    'id': 313369,
#    'original_language': 'en',
#    'original_title': 'La La Land',
#    'overview': 'Mia, an aspiring actress, serves lattes to movie stars in between auditions and Sebastian, a jazz musician, scrapes by playing cocktail party gigs in dingy bars, but as success mounts they are faced with decisions that begin to fray the fragile fabric of their love affair, and the dreams they worked so hard to maintain in each other threaten to rip them apart.',
#    'popularity': 88.015,
#    'poster_path': '/uDO8zWDhfWwoFdKS4fzkUJt0Rf0.jpg',
#    'release_date': '2016-11-29',
#    'title': 'La La Land',
#    'video': False,
#    'vote_average': 7.903,
#    'vote_count': 16818},
#   {'adult': False,
#    'backdrop_path': '/qaZ8CXv0thtQqZGRNbHuuZ9NlgT.jpg',
#    'genre_ids': [18, 35, 10749],
#    'id': 105789,
#    'original_language': 'en',
#    'original_title': 'Going Down in La-La Land',
#    'overview': 'A fresh face comes to Hollywood to act in movies but only the gay porn studios are eager to provide him with work.',
#    'popularity': 10.691,
#    'poster_path': '/tbgH8Fn3DPJzF5E7uxyjLAoPKIT.jpg',
#    'release_date': '2011-05-01',
#    'title': 'Going Down in LA-LA Land',
#    'video': False,
#    'vote_average': 5.8,
#    'vote_count': 48},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [35],
#    'id': 691191,
#    'original_language': 'en',
#    'original_title': 'LA LA Land',
#    'overview': 'What happens when a dim-witted New York Italian guy moves to Hollywood seeking fame and fortune? LA LA Land is the story of relentless Mikey Forearms, and his partner in stupidity Johnny, as they chase the dream and stumble their way through Hollywood\'s back doors. Armed with confidence if not talent, Mikey is anxious to get his career underway. Mikey unleashes himself on casting directors, but none of them appreciate his "acting chops". In the pilot episode he is offered a job that is not exactly what he had in mind. Following Johnny\'s suggestion, he meets Super Agent Jerry Flaxman and Big Shot Producer Alan Gilstein. Flaxman and Gilstein think they\'ve found the perfect pawn for their game, but maybe Mikey is not as dumb as he looks. Can he get his lucky break in LA LA Land?',
#    'popularity': 1.8,
#    'poster_path': '/nmdBXLTDzTaWzxcY32vz8CSpzbQ.jpg',
#    'release_date': '2008-03-07',
#    'title': 'LA LA Land',
#    'video': False,
#    'vote_average': 5.5,
#    'vote_count': 2},
#   {'adult': False,
#    'backdrop_path': '/pur6THv2H7qmXMu0Ft7bxft0jbg.jpg',
#    'genre_ids': [99, 10770],
#    'id': 579152,
#    'original_language': 'es',
#    'original_title': 'Las Hurdes, tierra con alma',
#    'overview': "A modern answer to Luis Buñuel's mythical documentary “Land Without Bread” (1933) about Las Hurdes, a historically impoverished region of the province of Cáceres, in Extremadura, Spain, and also a journey of discovery of the soul of this beautiful land and its inhabitants.",
#    'popularity': 0.679,
#    'poster_path': '/p2PBUGf7yURzHh4aTWOerRdrioG.jpg',
#    'release_date': '2015-09-17',
#    'title': 'Las Hurdes, a Land with Soul',
#    'video': False,
#    'vote_average': 5.5,
#    'vote_count': 2},
#   {'adult': False,
#    'backdrop_path': '/3sx25w8xK3YlGK53iKPniifU4P8.jpg',
#    'genre_ids': [99, 10402],
#    'id': 381083,
#    'original_language': 'en',
#    'original_title': 'Gary Numan: Android In La La Land',
#    'overview': 'The Godfather of electronic music is on a one-way trip to crack America, returning to the studio for the first time in nearly a decade. Android is a celebration of a music-making pioneer and the love story that helped him turn his life around.',
#    'popularity': 0.424,
#    'poster_path': '/1ZCglhextcg9Yc3PeFhIqW1hYPE.jpg',
#    'release_date': '2016-03-14',
#    'title': 'Gary Numan: Android In La La Land',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 10},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 578370,
#    'original_language': 'en',
#    'original_title': 'El indefinido. La crítica de La la land',
#    'overview': 'In a post-La la land world, a man must decide whether he loves or he hates it',
#    'popularity': 0.041,
#    'poster_path': '/oBMbXTSpvVomZsIefDPjyME6f2I.jpg',
#    'release_date': '2017-02-27',
#    'title': 'El indefinido. La crítica de La la land',
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 720687,
#    'original_language': 'en',
#    'original_title': 'Notre-Dame-des-Landes, la reconquête',
#    'overview': 'Continuation of the film The tarmac is in the meadow with Michel, the peasant historical figure of the fight against the airport, who will not have known in his lifetime the outcome of the fight of his life ... This new film is the story of  a "reconquest", that of the lands of Notre-Dame-des-Landes, a land reserve made available by the abandonment of the airport project.  It is the tale of a human and political adventure that pits residents with different visions about the future of their common territory, and tells of their confrontation with the State ...',
#    'popularity': 0.098,
#    'poster_path': '/mtGe2QOwLbrihsjpbyMbiR8XRHj.jpg',
#    'release_date': '2019-09-16',
#    'title': 'Notre-Dame-des-Landes, la reconquête',
#    'video': False,
#    'vote_average': 6.0,
#    'vote_count': 1},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [99],
#    'id': 480219,
#    'original_language': 'fr',
#    'original_title': "L'héroïque lande - La frontière brûle",
#    'overview': 'A growing city, where nearly 7,800 people lived, will be destroyed by 50% in February 2016. How will the 4,000 migrants expelled from the South zone reborn from their ashes in the northern zone. Before the state decided to annihilate the entire territory in October 2016 and to disperse its 11,000 inhabitants, to the four corners of France.',
#    'popularity': 0.251,
#    'poster_path': '/fOSQDBcO3qzbvIsoF7J32VPQnj0.jpg',
#    'release_date': '2018-04-11',
#    'title': 'The Wild Frontier',
#    'video': False,
#    'vote_average': 6.0,
#    'vote_count': 4},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 743876,
#    'original_language': 'es',
#    'original_title': 'El Milagro y el valor de la vida: Landriscina, Favaloro y Menapace',
#    'overview': '',
#    'popularity': 0.073,
#    'poster_path': '/xHv4fyt79sFddc2GccCRwBKw5dS.jpg',
#    'release_date': '1997-12-05',
#    'title': 'El Milagro y el valor de la vida: Landriscina, Favaloro y Menapace',
#    'video': True,
#    'vote_average': 10.0,
#    'vote_count': 1},
#   {'adult': False,
#    'backdrop_path': None,
#    'genre_ids': [],
#    'id': 1258979,
#    'original_language': 'fr',
#    'original_title': "DEMAIN S'ENTÊTE sur la ZAD de Notre Dame des Landes",
#    'overview': '',
#    'popularity': 0.001,
#    'poster_path': None,
#    'release_date': '',
#    'title': "DEMAIN S'ENTÊTE sur la ZAD de Notre Dame des Landes",
#    'video': False,
#    'vote_average': 0.0,
#    'vote_count': 0},
#   {'adult': False,
#    'backdrop_path': '/rg10dfOmhP42jTmVs0jRTPQ0WUE.jpg',
#    'genre_ids': [16, 35, 12, 10751],
#    'id': 121734,
#    'original_language': 'es',
#    'original_title': 'Las aventuras de Tadeo Jones',
#    'overview': 'Tad is a celebrity archaeologist and adventurer just like his hero Max Mordon... in his dreams! In reality, Tad is a Chicago construction worker. One day, however, he is mistaken for a real professor and takes his place on a flight to Peru in search of the lost city of Paititi.',
#    'popularity': 17.545,
#    'poster_path': '/vmysxjUJkYmp6CmjNOKOeHMOzFA.jpg',
#    'release_date': '2012-08-10',
#    'title': 'Tad, the Lost Explorer',
#    'video': False,
#    'vote_average': 6.2,
#    'vote_count': 567},
#   {'adult': False,
#    'backdrop_path': '/rAC8gH0rcaacud1xIt4iOvemqpk.jpg',
#    'genre_ids': [12, 28],
#    'id': 283322,
#    'original_language': 'mi',
#    'original_title': 'The Dead Lands',
#    'overview': 'Hongi, a Maori chieftain’s teenage son, must avenge his father’s murder in order to bring peace and honour to the souls of his loved ones after his tribe is slaughtered through an act of treachery. Vastly outnumbered by a band of villains led by Wirepa, Hongi’s only hope is to pass through the feared and forbidden “Dead Lands” and forge an uneasy alliance with a mysterious warrior, a ruthless fighter who has ruled the area for years.',
#    'popularity': 18.237,
#    'poster_path': '/wdlRuuA2CtS0KtaVzAikZxVHRIk.jpg',
#    'release_date': '2014-09-04',
#    'title': 'The Dead Lands',
#    'video': False,
#    'vote_average': 6.1,
#    'vote_count': 110},
#   {'adult': False,
#    'backdrop_path': '/lhfeI7duCKE8g8pqqTShRpPDdeu.jpg',
#    'genre_ids': [10751, 16, 10749, 12],
#    'id': 18269,
#    'original_language': 'en',
#    'original_title': "Lady and the Tramp II: Scamp's Adventure",
#    'overview': 'Lady and Tramp\'s mischievous pup, Scamp, gets fed up with rules and restrictions imposed on him by life in a family, and longs for a wild and free lifestyle. He runs away from home and into the streets where he joins a pack of stray dogs known as the "Junkyard Dogs." Buster, the pack\'s leader, takes an instant disliking to the "house-dog" and considers him a rival. Angel, a junkyard pup Scamp\'s age, longs for the safety and comfort of life in a family and the two become instant companions. Will Scamp choose the wild and free life of a stray or the unconditional love of his family?',
#    'popularity': 28.912,
#    'poster_path': '/nS3nhUZUSY8dWEsRmKILfiOC3F0.jpg',
#    'release_date': '2001-02-18',
#    'title': "Lady and the Tramp II: Scamp's Adventure",
#    'video': False,
#    'vote_average': 6.4,
#    'vote_count': 1241},
#   {'adult': False,
#    'backdrop_path': '/ssPh7tZwDtSurPf8rFPINIWkNvd.jpg',
#    'genre_ids': [18],
#    'id': 2438,
#    'original_language': 'en',
#    'original_title': 'The Country Girl',
#    'overview': 'An ex-theater actor is given one more chance to star in a musical yet his alcoholism may prevent it from happening.',
#    'popularity': 6.77,
#    'poster_path': '/7LdXybdZcTdZo7lkkrFQKf7byZf.jpg',
#    'release_date': '1954-12-15',
#    'title': 'The Country Girl',
#    'video': False,
#    'vote_average': 6.9,
#    'vote_count': 80},
#   {'adult': False,
#    'backdrop_path': '/xQa198uEb8DLwQntDwO9jlilXcC.jpg',
#    'genre_ids': [18, 36],
#    'id': 511,
#    'original_language': 'pl',
#    'original_title': 'Ziemia obiecana',
#    'overview': 'In nineteenth-century Łódź, Poland, three friends want to make a lot of money by building and investing in a textile factory. An exceptional portrait of rapid industrial expansion is shown through the eyes of one Polish town.',
#    'popularity': 9.257,
#    'poster_path': '/pjk8K5MpQJX0XczTC2KOVWNj0lC.jpg',
#    'release_date': '1975-02-21',
#    'title': 'The Promised Land',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 70},
#   {'adult': False,
#    'backdrop_path': '/pERcOAR1Teg4sLDDqRXj1TBjVsn.jpg',
#    'genre_ids': [28, 18, 36],
#    'id': 980026,
#    'original_language': 'da',
#    'original_title': 'Bastarden',
#    'overview': "Denmark, 1755. Captain Ludvig Kahlen sets out to conquer a Danish heath reputed to be uncultivable, with an impossible goal: to establish a colony in the name of the king, in exchange for a royal title. A single-minded ambition that the ruthless lord of the region will relentlessly seek to put down. Kahlen's fate hangs in the balance: will his endevours bring him wealth and honour, or cost him his life...?",
#    'popularity': 33.112,
#    'poster_path': '/npQgoOWn4fnvOIIyTj4rIV80FXC.jpg',
#    'release_date': '2023-10-05',
#    'title': 'The Promised Land',
#    'video': False,
#    'vote_average': 7.8,
#    'vote_count': 323},
#   {'adult': False,
#    'backdrop_path': '/c5nyI6ACiaIz8ELfgdkev6N91yp.jpg',
#    'genre_ids': [35],
#    'id': 119973,
#    'original_language': 'fr',
#    'original_title': 'La concierge',
#    'overview': 'A landlady is taunted by neighborhood kids.',
#    'popularity': 1.362,
#    'poster_path': '/elfDN8C1UNIH5hIB0eoE9kn6gF6.jpg',
#    'release_date': '1900-01-01',
#    'title': 'The Landlady',
#    'video': False,
#    'vote_average': 4.794,
#    'vote_count': 17},
#   {'adult': False,
#    'backdrop_path': '/yGgEg4yimYQJLZrZg3Qhogp2raQ.jpg',
#    'genre_ids': [10751, 16, 10749],
#    'id': 10340,
#    'original_language': 'en',
#    'original_title': 'Lady and the Tramp',
#    'overview': "Lady, a golden cocker spaniel, meets up with a mongrel dog who calls himself the Tramp. He is obviously from the wrong side of town, but happenings at Lady's home make her decide to travel with him for a while.",
#    'popularity': 47.042,
#    'poster_path': '/340NcWz9SQXWQyf4oicMxjbrLOb.jpg',
#    'release_date': '1955-06-22',
#    'title': 'Lady and the Tramp',
#    'video': False,
#    'vote_average': 7.121,
#    'vote_count': 5251},
#   {'adult': False,
#    'backdrop_path': '/zAoKH1cGILwwoe7dpMMyVIAom9a.jpg',
#    'genre_ids': [35, 28, 16, 12],
#    'id': 16907,
#    'original_language': 'ja',
#    'original_title': '劇場版 NARUTO 大活劇! 雪姫忍法帖だってばよ!!',
#    'overview': 'Naruto is thrilled when he is sent on a mission to protect his favorite actress, Yukie Fujikaze, on the set of her new movie, The Adventures of Princess Gale. But when the crew ventures out to film in the icy, foreboding Land of Snow, Yukie mysteriously flees! Naruto and his squad set off to find her... unaware that three Snow Ninja lie in wait, with a sinister purpose that will force Yukie to face her hidden past!',
#    'popularity': 31.822,
#    'poster_path': '/eUNRUeSNzm8LktH4HRaYiAReB6R.jpg',
#    'release_date': '2004-08-21',
#    'title': 'Naruto the Movie: Ninja Clash in the Land of Snow',
#    'video': False,
#    'vote_average': 7.2,
#    'vote_count': 544},
#   {'adult': False,
#    'backdrop_path': '/iwRCuHyaXLaG723n6RWbBGXgU29.jpg',
#    'genre_ids': [12, 28, 53, 878],
#    'id': 8810,
#    'original_language': 'en',
#    'original_title': 'Mad Max 2',
#    'overview': 'Max Rockatansky returns as the heroic loner who drives the dusty roads of a postapocalyptic Australian Outback in an unending search for gasoline. Arrayed against him and the other scraggly defendants of a fuel-depot encampment are the bizarre warriors commanded by the charismatic Lord Humungus, a violent leader whose scruples are as barren as the surrounding landscape.',
#    'popularity': 51.267,
#    'poster_path': '/dhVekfpaCW3QavAwGYbaQig87Xc.jpg',
#    'release_date': '1981-12-24',
#    'title': 'Mad Max 2',
#    'video': False,
#    'vote_average': 7.395,
#    'vote_count': 3735}],
#  'total_pages': 14,
#  'total_results': 274}

# %% [markdown]
# ## 통합본 -> 세분화

# %%
import requests
from odmantic import AIOEngine, Model
from motor.motor_asyncio import AsyncIOMotorClient
import asyncio
from typing import Optional, List

# Odmantic 모델 정의
class Movie(Model):
    movie_id: int
    title: str
    original_title: Optional[str] = None
    overview: Optional[str] = None
    poster_path: Optional[str] = None
    original_country: List[str] = []
    genre_ids: List[int]
    popularity: float
    release_date: Optional[str] = None
    cast: Optional[List[dict]] = None
    director: Optional[dict] = None

# API 헤더
HEADERS = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw",
}

# 단일 영화의 캐스트 및 감독 정보 가져오기
async def fetch_credit(movie_id: int) -> (List[dict], Optional[dict]):
    credits_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?language=ko-KR"
    response = await asyncio.to_thread(requests.get, credits_url, headers=HEADERS)
    credits_data = response.json()

    # 캐스트 정보 상위 8개
    cast = [
        {"cast_id": cast.get("id"), "name": cast.get("name")}
        for cast in credits_data.get("cast", [])[:8]
    ]

    # 감독 정보 필터링
    director = next(
        (
            {"id": crew["id"], "name": crew["name"]}
            for crew in credits_data.get("crew", [])
            if crew.get("job") == "Director"
        ),
        None,
    )

    return cast, director

# 단일 영화 상세 정보 가져오기
async def fetch_movie_details(movie_id: int):
    details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=ko-KR"
    response = await asyncio.to_thread(requests.get, details_url, headers=HEADERS)
    return response.json()

# 단일 영화 데이터를 처리하고 저장
async def process_movie(movie_id: int, engine):
    # 영화 상세 정보 호출
    details = await fetch_movie_details(movie_id)
    if not details or "id" not in details:
        print(f"Details not found for movie_id {movie_id}")
        return

    # 크레딧 정보 호출
    cast_info, director_info = await fetch_credit(movie_id)

    # MongoDB에 저장
    movie = Movie(
        movie_id=details["id"],
        title=details.get("title"),
        original_title=details.get("original_title"),
        overview=details.get("overview"),
        poster_path=details.get("poster_path"),
        original_country=details.get("origin_country", []), 
        genre_ids=[genre["id"] for genre in details.get("genres", [])],
        popularity=details.get("popularity", 0.0),
        release_date=details.get("release_date"),
        cast=cast_info,
        director=director_info,
    )
    await engine.save(movie)
    print(f"Saved movie_id {movie_id}")

# 검색 API로 영화 ID 가져오기
async def search_movies(search_query: str) -> List[int]:
    search_url = f"https://api.themoviedb.org/3/search/movie?query={search_query}&include_adult=false&language=ko-KR&page=1"
    response = await asyncio.to_thread(requests.get, search_url, headers=HEADERS)
    data = response.json()
    return [item["id"] for item in data.get("results", [])]

# 메인 처리 함수
async def fetch_and_store_movies(search_query: str):
    client = AsyncIOMotorClient("mongodb://user:team3@localhost:27017/")
    engine = AIOEngine(client=client, database="movies_db")

    # 검색 API 호출
    movie_ids = await search_movies(search_query)
    if not movie_ids:
        print("No movies found for the search query.")
        return

    # 각 영화 ID에 대해 처리
    tasks = [process_movie(movie_id, engine) for movie_id in movie_ids]
    await asyncio.gather(*tasks)
    print("모든 영화 데이터를 저장했습니다.")

# %%
import nest_asyncio
import asyncio

nest_asyncio.apply()

# 비동기 실행
if __name__ == "__main__":
    search_query = "비긴 어게인"  # 검색어를 외부에서 정의
    asyncio.run(fetch_and_store_movies(search_query))
# Out:
# Saved movie_id 198277
# 모든 영화 데이터를 저장했습니다.

# %% [markdown]
# ## 검색 분리

# %%
import requests
import pandas as pd
from typing import List, Optional
from odmantic import AIOEngine, Model
from motor.motor_asyncio import AsyncIOMotorClient
import asyncio


# Odmantic 모델 정의
class Movie(Model):
    movie_id: int
    title: str
    original_title: Optional[str] = None
    overview: Optional[str] = None
    poster_path: Optional[str] = None
    original_country: List[str] = []
    genres: List[str] = []
    popularity: float 
    release_date: Optional[str] = None
    cast: Optional[List[dict]] = None
    director: Optional[dict] = None


# SEARCH API 호출 및 결과 반환 함수
def search_movies(query: str) -> pd.DataFrame:
    url = f"https://api.themoviedb.org/3/search/movie?query={query}&include_adult=false&language=ko-KO&page=1"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw"
    }
    response = requests.get(url, headers=headers)
    data = response.json()

    if "results" in data:
        movies = [
            {
                "id": item["id"],
                "title": item.get("title"),
                "original_title": item.get("original_title"),
                "release_date": item.get("release_date"),
                "popularity": item.get("popularity")
            }
            for item in data["results"]
        ]
        return pd.DataFrame(movies)
    else:
        print("API 응답에 'results' 키가 없습니다.")
        return pd.DataFrame()

# %% [markdown]
# ### 중복 제거

# %%
import requests
import pandas as pd
from typing import List, Optional
from odmantic import AIOEngine, Model
from motor.motor_asyncio import AsyncIOMotorClient
import asyncio


# Odmantic 모델 정의
class Movie(Model):
    movie_id: int
    title: str
    original_title: Optional[str] = None
    overview: Optional[str] = None
    poster_path: Optional[str] = None
    original_country: List[str] = []
    genres: List[str] = []
    popularity: float 
    release_date: Optional[str] = None
    cast: Optional[List[dict]] = None
    director: Optional[dict] = None
    
# DETAIL 및 CREDIT API 호출 및 MongoDB 저장 함수
async def save_movie_to_db(movie_id: int):
    # MongoDB 연결 설정
    client = AsyncIOMotorClient("mongodb://root:team3@localhost:27017/")
    engine = AIOEngine(client=client, database="movies_db")

    # 기존 데이터 확인
    existing_movie = await engine.find_one(Movie, Movie.movie_id == movie_id)
    if existing_movie:
        print(f"영화 '{existing_movie.title}'는 이미 DB에 존재합니다. (movie_id: {movie_id})")
        return

    # DETAIL API 호출
    detail_url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=ko-KR"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw"
    }
    detail_response = requests.get(detail_url, headers=headers)
    detail_data = detail_response.json()

    # CREDIT API 호출
    credit_url = f"https://api.themoviedb.org/3/movie/{movie_id}/credits?language=ko-KR"
    credit_response = requests.get(credit_url, headers=headers)
    credit_data = credit_response.json()

    # 데이터 정리
    genres = [genre["name"] for genre in detail_data.get("genres", [])]
    cast = sorted(
        [{"cast_id": c["cast_id"], "name": c["name"]} for c in credit_data.get("cast", [])],
        key=lambda x: x["cast_id"]
    )[:8]
    director = next(
        (
            {"id": crew["id"], "name": crew["name"]}
            for crew in credit_data.get("crew", [])
            if crew.get("job") == "Director"
        ),
        None
    )

    # MongoDB 저장
    movie = Movie(
        movie_id=detail_data["id"],
        title=detail_data.get("title"),
        original_title=detail_data.get("original_title"),
        overview=detail_data.get("overview"),
        poster_path=detail_data.get("poster_path"),
        original_country=detail_data.get("origin_country"),
        genres=genres,
        popularity=detail_data.get("popularity"),
        release_date=detail_data.get("release_date"),
        cast=cast,
        director=director,
    )
    await engine.save(movie)
    print(movie)
    print(f"영화 '{movie.title}'가 MongoDB에 저장되었습니다.")

# %%
# MAIN 실행
if __name__ == "__main__":
    # Step 1: 검색 결과 반환
    query = input("검색어를 입력하세요: ")
    search_result = search_movies(query)
    if not search_result.empty:
        print("검색 결과:\n", search_result)
    else:
        print("검색 결과가 없습니다.")
# Out:
# 검색 결과:
#          id                 title        original_title release_date  \
# 0    20342            말할 수 없는 비밀                不能說的秘密   2007-07-27
# 1   643267    19금 정사: 말할 수 없는 비밀    19금 정사: 말할 수 없는 비밀   2016-08-18
# 2   797109            말할 수 없는 비밀            말할 수 없는 비밀   2023-10-17
# 3  1205834            말할 수 없는 비밀                言えない秘密   2024-06-28
# 4   734115  말할 수 없는 비밀 : 이모와의 관계  말할 수 없는 비밀 : 이모와의 관계   2020-07-06
#
#    popularity
# 0       9.183
# 1       0.338
# 2       1.523
# 3       3.601
# 4       6.323

# %%
# Step 2: 사용자 입력으로 상세 정보 저장
import nest_asyncio
nest_asyncio.apply()

movie_id = int(input("\n저장할 영화 ID를 입력하세요: "))
asyncio.run(save_movie_to_db(movie_id))
# Out:
# id=ObjectId('674ebf68e38a5f395f056a10') movie_id=20342 title='말할 수 없는 비밀' original_title='不能說的秘密' overview='예술학교로 전학 온 상륜(주걸륜)은 아버지의 영향을 받아 피아노에 천부적인 소질을 보인다. 학교를 둘러보던 중 신비스러운 피아노 연주가 흘러나오는 옛 음악실을 발견하게 되고, 그곳에서 샤오위(계륜미)를 만난다. 그들은 아름다운 피아노 선율처럼 즐거운 시간을 보내고, 둘 사이에는 애틋한 마음이 싹튼다. 그러나 상륜이 샤오위를 더 알고 싶어할 때마다 그녀는 비밀이라고 일관하며 의미심장한 미소만 짓는다. 어느 날 샤오위는 우연히 상륜이 같은 반 여학생 칭요와 키스하는 모습을 보게 되고, 그의 곁에서 사라지는데…' poster_path='/xvoXEBf4K1p68GtMSc5o00Z3f3e.jpg' original_country=['TW'] genres=['판타지', '드라마', '스릴러'] popularity=9.183 release_date='2007-07-27' cast=[{'cast_id': 1, 'name': '주걸륜'}, {'cast_id': 3, 'name': '계륜미'}, {'cast_id': 4, 'name': '황추생'}, {'cast_id': 5, 'name': 'Alice Tzeng'}, {'cast_id': 7, 'name': 'So Ming-Ming'}, {'cast_id': 11, 'name': 'Huang Jun-Lang'}, {'cast_id': 12, 'name': 'Zhan Yu-Hao'}, {'cast_id': 14, 'name': 'Du Guo-Zhang'}] director={'id': 17380, 'name': '주걸륜'}
# 영화 '말할 수 없는 비밀'가 MongoDB에 저장되었습니다.

# %%
import requests

url = "https://api.themoviedb.org/3/movie/489999?language=en-KR"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIyNmZlYzEwOGU3M2Y3YmVmNTkzYzM3N2RjMzdjYjcyZCIsIm5iZiI6MTczMjg2MjU3NC43Miwic3ViIjoiNjc0OTYyNmU0OTE5MDljMWI3OWRlY2VkIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.aumSeBsjfSdLck30QaMJjzeLi7ZZ4CMBOZS20p_AVdw"
}

response = requests.get(url, headers=headers)

response.json()
# Out:
# {'adult': False,
#  'backdrop_path': '/efy2NsyMUEDOnZW0hHA8VrCNsoU.jpg',
#  'belongs_to_collection': {'id': 1145924,
#   'name': 'Searching Collection',
#   'poster_path': '/jBJe6IHdgvoXXwx4MJVzUCsai7Z.jpg',
#   'backdrop_path': '/lltgYoY6rYCMvNLteZKGIdn6xbR.jpg'},
#  'budget': 1000000,
#  'genres': [{'id': 18, 'name': 'Drama'},
#   {'id': 9648, 'name': 'Mystery'},
#   {'id': 53, 'name': 'Thriller'}],
#  'homepage': 'http://www.searching.movie',
#  'id': 489999,
#  'imdb_id': 'tt7668870',
#  'origin_country': ['US', 'MX'],
#  'original_language': 'en',
#  'original_title': 'Searching',
#  'overview': "After David Kim's 16-year-old daughter goes missing, a local investigation is opened and a detective is assigned to the case. But 37 hours later and without a single lead, David decides to search the one place no one has looked yet, where all secrets are kept today: his daughter's laptop.",
#  'popularity': 21.437,
#  'poster_path': '/pk9R56ZFlofbBzfwBnHlDyg5DMs.jpg',
#  'production_companies': [{'id': 11341,
#    'logo_path': '/xytTBODEy3p20ksHL4Ftxr483Iv.png',
#    'name': 'Stage 6 Films',
#    'origin_country': 'US'},
#   {'id': 3287,
#    'logo_path': '/bz6GbCQQXGNE56LTW9dwgksW0Iw.png',
#    'name': 'Screen Gems',
#    'origin_country': 'US'},
#   {'id': 1038,
#    'logo_path': '/o62j8ZNXmRTrq6ThviFWiL9zb8J.png',
#    'name': 'Bazelevs Production',
#    'origin_country': 'RU'}],
#  'production_countries': [{'iso_3166_1': 'RU', 'name': 'Russia'},
#   {'iso_3166_1': 'US', 'name': 'United States of America'}],
#  'release_date': '2018-08-24',
#  'revenue': 75462037,
#  'runtime': 102,
#  'spoken_languages': [{'english_name': 'English',
#    'iso_639_1': 'en',
#    'name': 'English'}],
#  'status': 'Released',
#  'tagline': 'No one is lost without a trace.',
#  'title': 'Searching',
#  'video': False,
#  'vote_average': 7.583,
#  'vote_count': 3831}

# %% [markdown]
# ### 전체 데이터 가져오기

# %%
import asyncio
from odmantic import AIOEngine
from motor.motor_asyncio import AsyncIOMotorClient


# MongoDB에서 Movie 컬렉션의 데이터를 가져오는 함수
async def fetch_all_movies():
    # MongoDB 연결 설정
    client = AsyncIOMotorClient("mongodb://root:team3@localhost:27017/")
    engine = AIOEngine(client=client, database="movies_db")

    # 모든 영화 데이터를 가져오기
    movies = await engine.find(Movie)

    # 출력
    for movie in movies:
        print(f"ID: {movie.movie_id}, Title: {movie.title}, Genres: {movie.genres}")
    return movies

# %% [markdown]
# ### 장르만

# %%
# 비동기 함수 실행
if __name__ == "__main__":
    asyncio.run(fetch_all_movies())
# Out:
# ID: 313369, Title: 라라랜드, Genres: ['코미디', '드라마', '로맨스', '음악']

# %%
import asyncio
from odmantic import AIOEngine
from motor.motor_asyncio import AsyncIOMotorClient


# MongoDB에서 Movie 컬렉션의 데이터를 가져오는 함수
async def fetch_all_movies():
    # MongoDB 연결 설정
    client = AsyncIOMotorClient("mongodb://root:team3@localhost:27017/")
    engine = AIOEngine(client=client, database="movies_db")

    # 모든 영화 데이터를 가져오기
    movies = await engine.find(Movie)

    # 출력: 각 영화의 cast와 director 포함
    for movie in movies:
        print(f"ID: {movie.movie_id}, Title: {movie.title}")
        print(f"Genres: {movie.genres}")
        print(f"Cast: {movie.cast}")  # cast는 리스트로 저장됨
        print(f"Director: {movie.director}")  # director는 딕셔너리로 저장됨
        print("=" * 40)
    return movies


# 비동기 함수 실행
if __name__ == "__main__":
    asyncio.run(fetch_all_movies())
# Out:
# ID: 313369, Title: 라라랜드
# Genres: ['코미디', '드라마', '로맨스', '음악']
# Cast: [{'cast_id': 26, 'name': '라이언 고슬링'}, {'cast_id': 27, 'name': '엠마 스톤'}, {'cast_id': 28, 'name': 'Sandra Rosko'}, {'cast_id': 29, 'name': 'J.K. 시몬스'}, {'cast_id': 30, 'name': 'Finn Wittrock'}, {'cast_id': 31, 'name': '미즈노 소노야'}, {'cast_id': 32, 'name': '로즈메리 디윗'}, {'cast_id': 34, 'name': '존 레전드'}]
# Director: {'id': 136495, 'name': '데이미언 셔젤'}
# ========================================

# %%
import asyncio
import pandas as pd
from odmantic import AIOEngine
from motor.motor_asyncio import AsyncIOMotorClient


# MongoDB 연결 설정
client = AsyncIOMotorClient("mongodb://root:team3@localhost:27017/")
engine = AIOEngine(client=client, database="movies_db5")


# 데이터 가져오기 함수
async def fetch_movies():
    movies = await engine.find(Movie)

    # 영화 정보를 저장할 리스트
    movie_data = []

    for movie in movies:
        # cast에서 name만 필터링
        filtered_cast_names = [c["name"] for c in movie.cast] if movie.cast else None
        
        # director에서 name만 필터링
        director_name = movie.director["name"] if movie.director else None

        # 영화 정보를 딕셔너리로 저장
        movie_data.append({
            "Title": movie.title,
            "Genres": movie.genres,
            "Cast Names": filtered_cast_names,
            "Director Name": director_name,
            "Country": movie.original_country
        })

    # DataFrame 생성
    df = pd.DataFrame(movie_data)
    return df


# 비동기 실행
movie5 = asyncio.run(fetch_movies())

# %%
all_genres5 = [genre for genres in movie5["Genres"] for genre in genres]
genre_counts5 = pd.Series(all_genres5).value_counts().reset_index()
genre_counts5.columns = ["Genre", "Count"]

genre_counts5 = genre_counts5[genre_counts5['Count'] > 1]
genre_counts5
# Out:
#   Genre  Count
# 0   스릴러      5
# 1   드라마      5
# 2    범죄      4
# 3   코미디      3
# 4  미스터리      3
# 5    공포      2
# 6   판타지      2

# %%
all_genres5 = [genre for genres in movie5["Genres"] for genre in genres]
genre_counts5 = pd.Series(all_genres5).value_counts().reset_index()
genre_counts5.columns = ["Genre", "Count"]
genre_counts5

genre_counts5 = genre_counts5[genre_counts5['Count'] > 1]
genre_counts5
# Out:
#   Genre  Count
# 0   스릴러      5
# 1   드라마      5
# 2    범죄      4
# 3   코미디      3
# 4  미스터리      3
# 5    공포      2
# 6   판타지      2

# %%
genre_counts
# Out:
#   Genre  Count
# 0   드라마      7
# 1   로맨스      5
# 2   코미디      5
# 3    음악      4
# 4   판타지      2

# %%
all_casts = [genre for genres in df["Cast Names"] for genre in genres]
cast_counts = pd.Series(all_casts).value_counts().reset_index()
cast_counts.columns = ["Cast", "Count"]
cast_counts
# Out:
#             Cast  Count
# 0        라이언 고슬링      1
# 1          엠마 스톤      1
# 2   Sandra Rosko      1
# 3       J.K. 시몬스      1
# 4  Finn Wittrock      1
# 5        미즈노 소노야      1
# 6        로즈메리 디윗      1
# 7          존 레전드      1

# %%
all_countries4 = [genre for genres in df4["Country"] for genre in genres]
country_counts4 = pd.Series(all_countries4).value_counts().reset_index()
country_counts4.columns = ["Country", "Count"]
country_counts4
# Out:
#   Country  Count
# 0      US      3
# 1      KR      3
# 2      JP      2
# 3      AU      1
# 4      HK      1
# 5      FR      1
# 6      IT      1
# 7      GB      1

# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr
from sklearn.metrics.pairwise import cosine_similarity

# Store DataFrames in a list
genre_counts_list = [genre_counts, genre_counts2, genre_counts3, genre_counts4, genre_counts5]

# Merge all genres and create a unified DataFrame
all_genres = set()
for df in genre_counts_list:
    all_genres.update(df['Genre'])

all_genres = sorted(all_genres)  # Sort genres for consistency

# Create unified count DataFrame for all users
user_genre_matrix = pd.DataFrame({genre: [0] * len(genre_counts_list) for genre in all_genres})

for i, df in enumerate(genre_counts_list):
    for _, row in df.iterrows():
        user_genre_matrix.loc[i, row['Genre']] = row['Count']

# 1. Weighted Cosine Similarity
weighted_cosine_sim = cosine_similarity(user_genre_matrix)

# 2. Spearman Correlation
spearman_corr = np.zeros((len(genre_counts_list), len(genre_counts_list)))

for i in range(len(genre_counts_list)):
    for j in range(len(genre_counts_list)):
        corr, _ = spearmanr(user_genre_matrix.iloc[i], user_genre_matrix.iloc[j])
        spearman_corr[i, j] = corr

# Convert results to DataFrame for better visualization
weighted_cosine_df = pd.DataFrame(weighted_cosine_sim, columns=["규석", "정은", "수진", "영인", "우현"], index=["규석", "정은", "수진", "영인", "우현"])
spearman_corr_df = pd.DataFrame(spearman_corr, columns=["규석", "정은", "수진", "영인", "우현"], index=["규석", "정은", "수진", "영인", "우현"])

# Display results
print("Weighted Cosine Similarity:")
print(weighted_cosine_df)
print("\nSpearman Correlation:")
print(spearman_corr_df)
# Out:
# Weighted Cosine Similarity:
#           규석        정은        수진        영인        우현
# 규석  1.000000  0.723138  0.762913  0.544151  0.516091
# 정은  0.723138  1.000000  0.703953  0.582792  0.461061
# 수진  0.762913  0.703953  1.000000  0.732882  0.734182
# 영인  0.544151  0.582792  0.732882  1.000000  0.839894
# 우현  0.516091  0.461061  0.734182  0.839894  1.000000
#
# Spearman Correlation:
#           규석        정은        수진        영인        우현
# 규석  1.000000  0.547719  0.433962  0.073627  0.103907
# 정은  0.547719  1.000000  0.357724  0.169700 -0.066835
# 수진  0.433962  0.357724  1.000000  0.386757  0.487502
# 영인  0.073627  0.169700  0.386757  1.000000  0.624050
# 우현  0.103907 -0.066835  0.487502  0.624050  1.000000

# %%
weighted_cosine_df
# Out:
#           규석        정은        수진        영인        우현
# 규석  1.000000  0.723138  0.762913  0.544151  0.516091
# 정은  0.723138  1.000000  0.703953  0.582792  0.461061
# 수진  0.762913  0.703953  1.000000  0.732882  0.734182
# 영인  0.544151  0.582792  0.732882  1.000000  0.839894
# 우현  0.516091  0.461061  0.734182  0.839894  1.000000

# %%
spearman_corr_df
# Out:
#           규석        정은        수진        영인        우현
# 규석  1.000000  0.547719  0.433962  0.073627  0.103907
# 정은  0.547719  1.000000  0.357724  0.169700 -0.066835
# 수진  0.433962  0.357724  1.000000  0.386757  0.487502
# 영인  0.073627  0.169700  0.386757  1.000000  0.624050
# 우현  0.103907 -0.066835  0.487502  0.624050  1.000000

# %%
dfs = [movie, movie2, movie3, movie4, movie5] 

# Create sets of titles from each DataFrame
movies = [set(df['Title']) for df in dfs]

# %%
import pandas as pd
from itertools import combinations

# Calculate Jaccard similarity between all pairs of sets
results = []
for (i, s1), (j, s2) in combinations(enumerate(movies, start=1), 2):
    intersection = len(s1 & s2)
    union = len(s1 | s2)
    jaccard_similarity = intersection / union
    results.append({"Set1": i, "Set2": j, "Jaccard Similarity": jaccard_similarity})

# Convert results to a DataFrame
jaccard_df = pd.DataFrame(results)

# %%
jaccard_df
# Out:
#    Set1  Set2  Jaccard Similarity
# 0     1     2            0.111111
# 1     1     3            0.000000
# 2     1     4            0.052632
# 3     1     5            0.050000
# 4     2     3            0.000000
# 5     2     4            0.000000
# 6     2     5            0.050000
# 7     3     4            0.000000
# 8     3     5            0.000000
# 9     4     5            0.000000

# %%
movie5
# Out:
#            Title                Genres  \
# 0       위대한 레보스키             [코미디, 범죄]
# 1        이레이저 헤드                  [공포]
# 2      멀홀랜드 드라이브      [스릴러, 드라마, 미스터리]
# 3          블루 벨벳  [미스터리, 스릴러, 범죄, 로맨스]
# 4        토니 타키타니                 [드라마]
# 5   혐오스런 마츠코의 일생        [코미디, 드라마, 음악]
# 6             곡성            [공포, 미스터리]
# 7            굿타임             [범죄, 스릴러]
# 8     보 이즈 어프레이드        [코미디, 모험, 판타지]
# 9          언컷 젬스        [드라마, 스릴러, 범죄]
# 10    말할 수 없는 비밀       [판타지, 드라마, 스릴러]
#
#                                            Cast Names Director Name Country
# 0   [제프 브리지스, 존 굿맨, 줄리앤 무어, 스티브 부세미, David Huddles...         조엘 코엔    [US]
# 1   [Jack Nance, Charlotte Stewart, Allen Joseph, ...       데이비드 린치    [US]
# 2   [나오미 왓츠, Laura Harring, Ann Miller, Dan Hedaya...       데이비드 린치    [US]
# 3   [이사벨라 로셀리니, 카일 맥라클란, 데니스 호퍼, 로라 던, 호프 랭, Dean ...       데이비드 린치    [US]
# 4   [Takahumi Shinohara, 니시지마 히데토시, イッセー尾形, 미야자와 리...        이치가와 준    [JP]
# 5   [나카타니 미키, 나가야마 에이타, 이세야 유스케, 市川実日子, 黒沢あすか, 武田真...      나카시마 테츠야    [JP]
# 6         [곽도원, 황정민, 천우희, 장소연, 조한철, 쿠니무라 준, 김환희, 손강국]           나홍진    [KR]
# 7   [로버트 패틴슨, 제니퍼 제이슨 리, Barkhad Abdi, 베니 사프디, Mar...        조쉬 사프디    [US]
# 8   [호아킨 피닉스, 네이선 레인, 패티 루폰, 에이미 라이언, Kylie Rogers...        아리 애스터    [US]
# 9   [애덤 샌들러, Judd Hirsch, Eric Bogosian, 라키스 스탠필드,...        조쉬 사프디    [US]
# 10  [주걸륜, 계륜미, 황추생, Alice Tzeng, So Ming-Ming, Hua...           주걸륜    [TW]

# %%
df4
# Out:
#              Title                  Genres  \
# 0            헤이트풀8         [드라마, 미스터리, 서부]
# 1    반지의 제왕: 왕의 귀환           [모험, 판타지, 액션]
# 2               조커          [범죄, 스릴러, 드라마]
# 3  캐리비안의 해적: 망자의 함           [모험, 판타지, 액션]
# 4            서울의 봄  [드라마, 역사, 스릴러, 범죄, 전쟁]
# 5              기생충         [코미디, 스릴러, 드라마]
# 6         보헤미안 랩소디               [음악, 드라마]
# 7            건축학개론              [코미디, 로맨스]
# 8            존 윅 4           [액션, 스릴러, 범죄]
# 9           쇼생크 탈출               [드라마, 범죄]
#
#                                           Cast Names Director Name   Country
# 0  [사무엘 L. 잭슨, 커트 러셀, 월튼 고긴스, 제니퍼 제이슨 리, 팀 로스, 조이...      쿠엔틴 타란티노      [US]
# 1  [일라이저 우드, 이안 맥켈런, 비고 모텐슨, 리브 타일러, 올랜도 블룸, 존 라이...         피터 잭슨      [US]
# 2  [재지 비츠, 로버트 드 니로, 프랜시스 콘로이, Josh Pais, 마크 매런, ...        토드 필립스      [US]
# 3  [키이라 나이틀리, 올랜도 블룸, Jack Davenport, 빌 나이, 스텔란 스...       고어 버빈스키      [US]
# 4  [황정민, 정우성, 박해준, 이성민, 김성균, Choe Min, 전진기, Yum D...           김성수      [KR]
# 5           [송강호, 이선균, 조여정, 최우식, 박소담, 장혜진, 이정은, 정지소]           봉준호      [KR]
# 6  [벤 하디, Gwilym Lee, Joseph Mazzello, 루시 보인턴, 마이...       브라이언 싱어  [US, GB]
# 7            [한가인, 이제훈, 수지, 고준희, 엄태웅, 유연석, 조정석, 조현철]           이용주      [KR]
# 8  [키아누 리브스, 견자단, 빌 스카스가드, 이언 맥셰인, 로렌스 피시번, 랜스 레딕...      채드 스타헬스키      [US]
# 9  [팀 로빈스, 모건 프리먼, Bob Gunton, William Sadler, 클랜...      프랭크 다라본트      [US]
